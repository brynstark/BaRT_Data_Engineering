# %% [markdown]
# # Twitter API Streaming
#
# To stream the data and save it to json files, I'll use tweepy, as adapted from [Brian Spiering's code](https://github.com/brianspiering/fun_with_twitter/blob/master/tweepy_writer/demo_tweepy_writer.ipynb).

# %%
reset -fs

# %%
my_consumer_key = '[]'
my_consumer_secret = '[]'
my_access_token = '[]'
my_access_token_secret = '[]'

# %%
import json
import os
import sys

from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream

auth = OAuthHandler(my_consumer_key, my_consumer_secret)
auth.set_access_token(my_access_token, my_access_token_secret)

class WriteToDiskListener(StreamListener):
    """Write stream listener to disk with limited number of Tweets.
    """

    def __init__(self, filename, limit=5):
        self.counter = 0
        self.filename = filename
        self.limit = limit
        
    def on_data(self, data):
        "If under limit, write received data to disk."
        while self.counter < self.limit:
            try:
                with open(self.filename.lower()+'.json', 'a') as f:
                    f.write(data)
                self.counter += 1
                return True
            except BaseException as e:
                print("Error on_data: {}".format(e))
            return True
        else:
            return False
 
    def on_error(self, status):
        print(status)

if __name__ == '__main__':    
    track = sys.argv[1:] # Track is a list of search terms to stream.
    filename = "_".join([item.lower() for item in track])

    # # Remove existing file of tweets
    # try:
    #     os.remove(filename+'.json')
    # except OSError:
    #     pass

    listener = WriteToDiskListener(filename=filename, 
                                    limit=5)
    stream = Stream(auth, listener)

    try:
        stream.filter(track=track,
                      languages=['en'])
    except:
        stream.disconnect()

# %%
! python3 twitter_streaming.py train

# %%
! python3 twitter_streaming.py oakland

# %%
import json
from pprint import pprint

# %%
data = []

with open('oakland.json') as data_file:
    for line in data_file:
        tweet = json.loads(line)
        data.append(tweet)

# %%
# I've printed 5 tweets to the file, so let's check that:
print(len(data))
# Out:
# 5

# %%
# The data for each tweet
data[0].keys()
# Out:
# dict_keys(['id_str', 'truncated', 'timestamp_ms', 'contributors', 'is_quote_status', 'favorited', 'in_reply_to_status_id', 'place', 'retweeted_status', 'user', 'in_reply_to_status_id_str', 'in_reply_to_user_id_str', 'in_reply_to_user_id', 'extended_entities', 'in_reply_to_screen_name', 'lang', 'retweet_count', 'entities', 'retweeted', 'created_at', 'geo', 'coordinates', 'possibly_sensitive', 'id', 'source', 'text', 'filter_level', 'favorite_count'])

# %% [markdown]
# The data that will be useful to us is the Tweet's text, as well as the time it was created, and possibly the location if that info is available (although that may depend on an individual user's settings).

# %%
for tweet in data:
    pprint(tweet['text'])
    pprint(tweet['created_at'])
    print()
# Out:
# ('RT @SouthLoneStar: Oakland PD Front Door.\n'
#  '#Blacklivesmatter are violent thugs. All PD should buy more robots to fight '
#  'them! https://t.co/SD…')
# 'Mon Jul 11 00:35:44 +0000 2016'
#
# 'Bro you trippen Benihana fire  https://t.co/rjVNt5sYQW'
# 'Mon Jul 11 00:35:52 +0000 2016'
#
# ('RT @hautedamn: "Peaceful" protestors shutting down a highway in Oakland, '
#  'California. https://t.co/sxBesgFCkE')
# 'Mon Jul 11 00:35:56 +0000 2016'
#
# ('250 W GOLDEN GATE, DETROIT, MI 48203 -Metro Detroit Real Estate, Oakland '
#  'County Properties, Macomb County Properties…https://t.co/6cNrbSQhy3')
# 'Mon Jul 11 00:35:58 +0000 2016'
#
# ('RT @Mahi_The_Giant: So taco trucks are trash in the bay? 🤔🤔🤔 '
#  'https://t.co/IIej5PKcPf')
# 'Mon Jul 11 00:35:59 +0000 2016'

# %% [markdown]
# Now let's try to hone our filter so that when we set it loose on our helpless Tweeters, we'll actually get helpful tweets.

# %%
! python3 twitter_streaming.py bart train

# %%
data = []

with open('bart_train.json') as data_file:
    for line in data_file:
        tweet = json.loads(line)
        data.append(tweet)

# %%
for tweet in data:
    pprint(tweet['text'])
    pprint(tweet['created_at'])
    print()
# Out:
# ('RT @nzherald: Syrian refugees sang and danced in the aisles of a train on an '
#  "'awesome' trip across the Otago countryside https://t.co/4c2X0…")
# 'Mon Jul 11 01:03:46 +0000 2016'
#
# ('@BarackObama @HillaryClinton @realDonaldTrump \n'
#  'TRUMP TRAIN FIRED UP FULL STEAM AHEAD.\n'
#  'GOOD BYE EXECUTIVE ORDERS!!!! https://t.co/nmF5QvRA9g')
# 'Mon Jul 11 01:03:47 +0000 2016'
#
# 'RT @GymGoers: Train together, stay together. ✌🏼️ https://t.co/i8dtHh2KGl'
# 'Mon Jul 11 01:03:47 +0000 2016'
#
# ('RT @kateefeldman: A guy just told his girlfriend to hold the train while he '
#  'caught a Pokémon and she got on and left without him.')
# 'Mon Jul 11 01:03:48 +0000 2016'
#
# 'Yay awesome! https://t.co/mOY7on49XC'
# 'Mon Jul 11 01:03:50 +0000 2016'

# %% [markdown]
# This code enters keywords as either 'bart' or 'train', so naturally most of the tweets have to do with trains other than BART.

# %%
# After specifying the query in twitter_streaming.py
! python3 twitter_streaming.py

# %%
data = []

with open('bay area.json') as data_file:
    for line in data_file:
        tweet = json.loads(line)
        data.append(tweet)

# %%
for tweet in data:
    pprint(tweet['text'])
    pprint(tweet['created_at'])
    print()
# Out:
# ("@jeaaabooty @_theyloveashhh they don't exist in Wackramento, getchoself a "
#  'bay area nigga!!!! 12/10 highly recommended')
# 'Mon Jul 11 02:40:10 +0000 2016'
#
# ('RT @DarwinBondGraha: #Oakland protest has gained numbers. #BlackLivesMatter '
#  'https://t.co/NCP4YKfGWG')
# 'Mon Jul 11 02:40:19 +0000 2016'
#
# ('Watching #MadBum crush this game, just like sonjachrista crushed this ice '
#  'cream sandwich. #SF… https://t.co/Or2lF8woX5')
# 'Mon Jul 11 02:42:14 +0000 2016'
#
# ("I'm in San Francisco and I was super bummed I wasn't at the ball yard for "
#  "Bumgardner's no no but... that's over now. ⚾️")
# 'Mon Jul 11 02:42:15 +0000 2016'
#
# "Frisco's Ryan Cordell hit his 16th HR. @RidersBaseball @Rangers"
# 'Mon Jul 11 02:42:15 +0000 2016'
#
# 'I hate the San Francisco Giants'
# 'Mon Jul 11 02:42:21 +0000 2016'
#
# ('RT @DarenEpley: Devils win Pastime 17 U World Series championship 5-1 over '
#  "South Oakland A's!!!  Fairfield with the win. Skibba the save.")
# 'Mon Jul 11 02:42:21 +0000 2016'

# %% [markdown]
# Collecting tweets instead about all of the Bay Area in general, we can later filter for Tweets that might be relevant to BART passengers. Now let's open this up to consume more than 10 tweets! I'm gonna go for 5,000...

# %% [markdown]
# __Checking what's in 'bay area.json':__

# %%
data = []

with open('/Users/brynstark/Stark gU/bay area.json') as data_file:
    for line in data_file:
        tweet = json.loads(line)
        data.append(tweet)

# %%
for tweet in data:
    pprint(tweet['text'])
    pprint(tweet['created_at'])
    print()
# Out:
# 'bay area by my lonely. miss my boo 😞'
# 'Mon Jul 11 02:59:11 +0000 2016'
#
# ('New from bay area! jenni jiggles striptease aimed 2please chico escorts '
#  '#Chico #escorts #adult #xxx https://t.co/RdYfGL9VhS')
# 'Mon Jul 11 02:59:14 +0000 2016'
#
# ('RT @prisonculture: Here are some good and useful suggestions. '
#  'https://t.co/s3XMDxVDE6')
# 'Mon Jul 11 02:59:14 +0000 2016'
#
# ('#News: Darvish good after rehab start, could rejoin Rangers soon: FRISCO, '
#  'Texas (AP) — Right-hander Yu Da... https://t.co/RbO1FbqYrX #TU')
# 'Mon Jul 11 02:59:15 +0000 2016'
#
# ('@Wink_Marvel @ESPNSteinLine pg:goran, sg: https://t.co/xps4oIbqSR, sf: '
#  'winslow, pf: bosh/reed/ud, c:whiteside plus cap space dummy')
# 'Mon Jul 11 02:59:21 +0000 2016'
#
# ('RT @KianJcUpdates: Kian arriving at the venue in Richmond! '
#  'https://t.co/iA1ZzwL9KR')
# 'Mon Jul 11 02:59:21 +0000 2016'
#
# ('RT @A_S_Alexander: So many ways to show up! 26 Ways to Be in the Struggle '
#  'Beyond the Streets https://t.co/As2g4NMM3M #blacklivesmatter #mov…')
# 'Mon Jul 11 02:59:21 +0000 2016'
#
# ('Federer Escapes, Moves Into Wimbledon SF│ATP World Tour '
#  'https://t.co/HlbCHgkGI5')
# 'Mon Jul 11 02:59:22 +0000 2016'
#
# ("@MrJayBenz @JrLuvsSports I used to hate it. Thought it was too generic. It's "
#  'grown on me. As a "SF guy",Wouldn\'t be mad if they kept it')
# 'Mon Jul 11 02:59:28 +0000 2016'
#
# ('@ItsMicahC I still support the light skin community but the Bay Area gained '
#  'that Mega L 😂😂😂')
# 'Mon Jul 11 02:59:29 +0000 2016'
#
# ('RT @LillyMaryPinto: Thanks for making our life safe &amp; peaceful . We '
#  'salute your dedication &amp; efforts for making civilian life secure https:…')
# 'Mon Jul 11 02:59:29 +0000 2016'
#
# ('RT @prisonculture: Here are some good and useful suggestions. '
#  'https://t.co/s3XMDxVDE6')
# 'Mon Jul 11 02:59:30 +0000 2016'
#
# ("Giants' Bumgarner loses no-hitter after 7 1/3 innings: SAN FRANCISCO (AP) — "
#  'Giants left-hander Madison Bumgar... https://t.co/OjfopErigM')
# 'Mon Jul 11 02:59:32 +0000 2016'
#
# ("RT @blackvoices: From San Fran to D.C., many parts of America didn't stay "
#  'silent last night #BlackLivesMatter https://t.co/DhvY2yqOvB https…')
# 'Mon Jul 11 02:59:34 +0000 2016'
#
# ("I can't wait to see @benthefisherman come out and perform in Oakland again "
#  'we gotta make this shit happen ASAP')
# 'Mon Jul 11 02:59:34 +0000 2016'
#
# 'San Francisco pier is pretty lit rn'
# 'Mon Jul 11 02:59:34 +0000 2016'
#
# ('RT @prisonculture: Here are some good and useful suggestions. '
#  'https://t.co/s3XMDxVDE6')
# 'Mon Jul 11 02:59:35 +0000 2016'
#
# ("@CarolineRhodess that's horribleeee😩 I loved Alcatraz it was interesting and "
#  'the view of San Francisco was amazing. I wanna live there')
# 'Mon Jul 11 02:59:46 +0000 2016'
#
# ('That/ the way Giants!!!! — watching Arizona Diamondbacks vs San Francisco '
#  'Giants')
# 'Mon Jul 11 02:59:47 +0000 2016'
#
# ("(Mercury News) A's first half: #Injuries not only reason for 38-51 record : "
#  "Oakland's.. https://t.co/tLiEkXkmkV https://t.co/iHpCKrlmb1")
# 'Mon Jul 11 02:59:49 +0000 2016'
#
# ("[Fox Sports] Giants' Bumgarner loses no-hitter after 7 1/3 innings "
#  'https://t.co/RMjUHDZzpG #SFGiants')
# 'Mon Jul 11 02:59:50 +0000 2016'
#
# ('RT @prisonculture: Here are some good and useful suggestions. '
#  'https://t.co/s3XMDxVDE6')
# 'Mon Jul 11 02:59:52 +0000 2016'
#
# 'RT @dawntrinh: @HippieSabotage San Francisco at 1015 Folsom this time ❤️'
# 'Mon Jul 11 02:59:57 +0000 2016'
#
# ('@gangmariayi drawing with hair in face @ Portal Oakland '
#  'https://t.co/lr9pyvUz4A')
# 'Mon Jul 11 02:59:52 +0000 2016'
#
# ('At the Oakland 880 protest I was on the front line reminding all the "white '
#  'allies" that if they were serious they\'d be on the front lines')
# 'Mon Jul 11 02:59:58 +0000 2016'
#
# 'Real shit 😈😈😈😈 https://t.co/b0C0jeCtyR'
# 'Mon Jul 11 03:00:00 +0000 2016'
#
# ("RT @Nxrdstrom: I can't wait to see @benthefisherman come out and perform in "
#  'Oakland again we gotta make this shit happen ASAP')
# 'Mon Jul 11 03:00:01 +0000 2016'
#
# ('RT @KianJcUpdates: Harrison joined the challenge | Richmond '
#  'https://t.co/c2vaT8DqyB')
# 'Mon Jul 11 03:00:01 +0000 2016'
#
# ('Oxymels, Shrubs, and Switchels, oh my! Join me for a workshop at '
#  '#HomesteadApothecary https://t.co/KuwPLi5cT6 #oakland #temescalalley')
# 'Mon Jul 11 03:00:01 +0000 2016'
#
# ('Simple debuted 5-27-94 Warfield Theatre, San Francisco, CA '
#  'https://t.co/ZCmEMgsElt #phish')
# 'Mon Jul 11 03:00:01 +0000 2016'
#
# ('RT @barbs73: We SEE you Baton Rouge, DC, Dallas, STL, OKC, Memphis, St.Paul, '
#  'Fresno, Pittsb, SF, Portland, Miami, Columbus &amp; Berlin! #Black…')
# 'Mon Jul 11 03:00:02 +0000 2016'
#
# ('san francisco companies networking PDF Ebook - https://t.co/7bCp3W9lXp  #san '
#  '#francisco #companies #networking')
# 'Mon Jul 11 03:00:03 +0000 2016'
#
# ("RT @JustinTrudeau: Congratulations to Richmond Hill's Denis Shapovalov, "
#  "winner of the #Wimbledon boys' singles title. Your future is bright!")
# 'Mon Jul 11 03:00:05 +0000 2016'
#
# ('Strong quake shakes coastal area in northwestern Ecuador - San Francisco '
#  'Chronicle https://t.co/X7rRJV8d92')
# 'Mon Jul 11 03:00:07 +0000 2016'
#
# "It's way too quiet in SF tonight. My people where ya at"
# 'Mon Jul 11 03:00:09 +0000 2016'
#
# ("RT @ByRosenberg: One of world's richest towns (median income: $250k) may "
#  'block plan for faster, greener Silicon Valley train service https:…')
# 'Mon Jul 11 03:00:14 +0000 2016'
#
# 'RT @CHANNINGPOSTERS: Good morning from San Francisco. https://t.co/ccaX07uYPR'
# 'Mon Jul 11 03:00:03 +0000 2016'
#
# ('VTG SAN FRANCISCO GIANTS JERSEY SEWN SZ 48 RAWLINGS  EXCELLENT COND '
#  'https://t.co/dFDWgsCmuv https://t.co/q9ax10xOGn')
# 'Mon Jul 11 03:00:14 +0000 2016'
#
# ('VTG SAN FRANCISCO GIANTS JERSEY SEWN SZ 48 RAWLINGS  EXCELLENT COND '
#  'https://t.co/oQYt1MqLj4 https://t.co/ZxvQioXx7T')
# 'Mon Jul 11 03:00:14 +0000 2016'
#
# ('@LeftSentThis on this topic... someone standing next to me took this picture '
#  'in Oakland last week. https://t.co/wvXop2R3UY')
# 'Mon Jul 11 03:00:16 +0000 2016'
#
# ("i just got on my plane &amp; we're about to leave so I'll see you in 12 "
#  'hours san francisco 💗💗')
# 'Mon Jul 11 03:00:18 +0000 2016'
#
# 'RT @brianshall: All of San Francisco right now. https://t.co/nbWJDOqXAZ'
# 'Mon Jul 11 03:00:18 +0000 2016'
#
# ('BERKELEY DOCTOR SAYS MORE PEOPLE DIE FROM CHEMOTHERAPY THAN FROM CANCER '
#  '[VIDEO] https://t.co/2op6ctcHhN')
# 'Mon Jul 11 03:00:20 +0000 2016'
#
# ('The universe is closer than you think A GIFT FROM THE STARS #Regency #SF '
#  '#PUYB #CR4U #IARTG https://t.co/YjaMIoCfX9 https://t.co/M8dzL7lYaE')
# 'Mon Jul 11 03:00:21 +0000 2016'
#
# ('RT @A_S_Alexander: So many ways to show up! 26 Ways to Be in the Struggle '
#  'Beyond the Streets https://t.co/As2g4NMM3M #blacklivesmatter #mov…')
# 'Mon Jul 11 03:00:23 +0000 2016'
#
# ('Short Stay The Ritz Carlton, San Francisco, California, Usa … : '
#  'https://t.co/Z1cr7e77wd ,,, https://t.co/ZA8zTlAIqx')
# 'Mon Jul 11 03:00:24 +0000 2016'
#
# ('RT @A_S_Alexander: So many ways to show up! 26 Ways to Be in the Struggle '
#  'Beyond the Streets https://t.co/As2g4NMM3M #blacklivesmatter #mov…')
# 'Mon Jul 11 03:00:25 +0000 2016'
#
# "What's all this noise in Oakland all of a sudden?"
# 'Mon Jul 11 03:00:25 +0000 2016'
#
# ('RT @prisonculture: Here are some good and useful suggestions. '
#  'https://t.co/s3XMDxVDE6')
# 'Mon Jul 11 03:00:26 +0000 2016'
#
# ('Hands down my favorite song ever. \n'
#  '\n'
#  'Listen to Distant Lover (Live 1974 At the Oakland Coliseum) by Marvin Gaye '
#  'https://t.co/t7K5vycOoX')
# 'Mon Jul 11 03:00:28 +0000 2016'
#
# ("Heading to Japan! I've been waiting for this trip since I was a kid... @ San "
#  'Francisco… https://t.co/UDZo1EYlnm')
# 'Mon Jul 11 03:00:29 +0000 2016'
#
# ("@JordonCooper You know what's happened with the Oakland PD since this was "
#  'published, right?')
# 'Mon Jul 11 03:00:29 +0000 2016'
#
# ("RT @Running_experts: Giants' Bumgarner Has No-Hitter Through 6 Innings: "
#  'Madison Bumgarner of the San Francisco Giants has a no-hitter… http…')
# 'Mon Jul 11 03:00:29 +0000 2016'
#
# ("San Francisco's @ShannonRowbury is headed to @Rio2016_en after top three "
#  "finish in the 1,500 meters. That's track, not @USAGym")
# 'Mon Jul 11 03:00:30 +0000 2016'
#
# ('New Jobs from Land Rover: Warranty Assistnat, Jobs in Frisco, Texas, United '
#  'States https://t.co/KOV47OXUKc #jobsearch')
# 'Mon Jul 11 03:00:35 +0000 2016'
#
# ('UC Berkeley Admitting 1,000 More California Students Than Last Year '
#  'https://t.co/ndLwxr3lk4')
# 'Mon Jul 11 03:00:35 +0000 2016'
#
# 'Weather now: clear sky, 75°F, 24 mph west wind. https://t.co/Jz1tlOOONV'
# 'Mon Jul 11 03:00:36 +0000 2016'
#
# 'RT @Brilliant_Ads: San Francisco Zoo: “Meet A Giraffe” https://t.co/ZfTs2oziUm'
# 'Mon Jul 11 03:00:36 +0000 2016'
#
# ('Download our iOS app for latest news and weather in San Francisco. Local Now '
#  'wishes you a great Sunday evening! https://t.co/mcHAkggptu')
# 'Mon Jul 11 03:00:36 +0000 2016'
#
# ('UC Berkeley Admitting 1,000 More California Students Than Last Year '
#  'https://t.co/LYuiAF7L2I https://t.co/eqrZhxxf4H')
# 'Mon Jul 11 03:00:37 +0000 2016'
#
# 'RT @TheView617: "They\'re not that bad"  https://t.co/R4cDNv0IR4'
# 'Mon Jul 11 03:00:40 +0000 2016'
#
# 'Just posted a photo @ Oakland, California https://t.co/i0izV8CduE'
# 'Mon Jul 11 03:00:40 +0000 2016'
#
# ("RT @ElliottAlmond: San Francisco's @ShannonRowbury is headed to @Rio2016_en "
#  "after top three finish in the 1,500 meters. That's track, not @…")
# 'Mon Jul 11 03:00:41 +0000 2016'
#
# ('RT @booksbyjoy: san francisco companies networking PDF Ebook - '
#  'https://t.co/7bCp3W9lXp  #san #francisco #companies #networking')
# 'Mon Jul 11 03:00:42 +0000 2016'
#
# "RT @JABALIBARRETT: 'Girl From Oakland' by PND is so slept on. I'm convinced."
# 'Mon Jul 11 03:00:42 +0000 2016'
#
# '@dj_shaffy except im in berkeley...'
# 'Mon Jul 11 03:00:43 +0000 2016'
#
# ("7 1/3 innings is Bumgarner's longest start allowing no hits. Had a 7-inning "
#  'game that Justin Morneau broke up with… https://t.co/zKpVRef4bY')
# 'Mon Jul 11 03:00:35 +0000 2016'
#
# ("RT @AntiochTweets: This movie bouta be lit!! It's based in the Bay Area "
#  'https://t.co/rOW0fiWf1E')
# 'Mon Jul 11 03:00:49 +0000 2016'
#
# ('"Don\'t you give up on Frisco.... What you two have is very, very precious." '
#  '#Dulicia #DnA4ever #FnF #DukeLives #GH')
# 'Mon Jul 11 03:00:50 +0000 2016'
#
# "RT @j2trippy: I'm really from Oakland doe... https://t.co/KaD5Al5Fgi"
# 'Mon Jul 11 03:00:51 +0000 2016'
#
# ('#Richmond #Job Seasonal Travel RN - Medical Intensive Care Unit - '
#  '(Richmond): Job Description:Seasonal Nation... https://t.co/19NZJtSMCr')
# 'Mon Jul 11 03:00:52 +0000 2016'
#
# ('RT @A_S_Alexander: So many ways to show up! 26 Ways to Be in the Struggle '
#  'Beyond the Streets https://t.co/As2g4NMM3M #blacklivesmatter #mov…')
# 'Mon Jul 11 03:00:52 +0000 2016'
#
# ('#Richmond #Job RN / Medical Surgical - Located In - (Richmond): Job '
#  'Description:Medical Staffing Network Trav... https://t.co/4FZ90dvNuO')
# 'Mon Jul 11 03:00:52 +0000 2016'
#
# ('#Richmond #Job Dining Services Director - (University Of Richmond): '
#  'Overview:The Dining Services Director lea... https://t.co/w6yX8rXMli')
# 'Mon Jul 11 03:00:52 +0000 2016'
#
# ('Pictures of people who now want MORE governmentThe Height Of Hippie Power: '
#  '55 Photos Of San Francisco In The 1960s https://t.co/shmf9ZXHK9')
# 'Mon Jul 11 03:00:54 +0000 2016'
#
# ('RT @TGAsuperheroes: Our fab #techgirls Team Pawsout on way to technovation '
#  'global challenge in San Fran! #stem… https://t.co/CYoaA1aXDL')
# 'Mon Jul 11 03:00:54 +0000 2016'
#
# ('#blackandwhite #sanfrancisco #skyline from #berkeley #sf #bayarea '
#  '#citybythebay #travel #travelphotography #nikon https://t.co/sNQBWdupV3')
# 'Mon Jul 11 03:00:54 +0000 2016'
#
# 'RT @brianshall: All of San Francisco right now. https://t.co/nbWJDOqXAZ'
# 'Mon Jul 11 03:00:57 +0000 2016'
#
# ('RT @A_S_Alexander: So many ways to show up! 26 Ways to Be in the Struggle '
#  'Beyond the Streets https://t.co/As2g4NMM3M #blacklivesmatter #mov…')
# 'Mon Jul 11 03:00:57 +0000 2016'
#
# ('M.Seles started playing tennis at a relatively late age of 9 years old yet '
#  'only 6 years later made her 1st Slam SF losing in 3 to Graf at RG')
# 'Mon Jul 11 03:00:57 +0000 2016'
#
# ('San Francisco has sooo many landmarks and Pokemon everywhere.. It was a good '
#  'day')
# 'Mon Jul 11 03:00:58 +0000 2016'
#
# "RT @MARKCURRY: 71st Life long friends,Oakland Ca' https://t.co/9y5Gy5rz3c"
# 'Mon Jul 11 03:00:44 +0000 2016'
#
# ('Although, this Taoiseach hunt is a blessing in not so much disguise. Maybe '
#  'someone from SF will take over. Rule the country into sanity.')
# 'Mon Jul 11 03:00:59 +0000 2016'
#
# ("RT @AntiochTweets: This movie bouta be lit!! It's based in the Bay Area "
#  'https://t.co/rOW0fiWf1E')
# 'Mon Jul 11 03:01:01 +0000 2016'
#
# ('{#SummerTime} Sunny Sundays in Telegraph Hill @ San Francisco, California '
#  'https://t.co/6tlX7VRbAB')
# 'Mon Jul 11 03:01:03 +0000 2016'
#
# ('3-Methylpentane (1.76 PPB) detected above threshold ( &gt;0.0 PPB) @ '
#  'Richmond: Atchison Village Area - Community Location - 2016-07-10 20:01:02')
# 'Mon Jul 11 03:01:03 +0000 2016'
#
# ('RT @prisonculture: Here are some good and useful suggestions. '
#  'https://t.co/s3XMDxVDE6')
# 'Mon Jul 11 03:01:04 +0000 2016'
#
# ('Protesters gather at San Francisco City Hall over police killings in Dallas '
#  '- KGO-TV https://t.co/b5sko9tXjv')
# 'Mon Jul 11 03:01:06 +0000 2016'
#
# 'RT @kekebruuh: Dumb ass East Oakland 😂🤘🏽 https://t.co/Oy02FHuzcG'
# 'Mon Jul 11 03:01:07 +0000 2016'
#
# "REGGIE JACKSON OAKLAND A'S UNSIGNED 8X10 by Unknown https://t.co/46cKb9RMgv"
# 'Mon Jul 11 03:01:08 +0000 2016'
#
# ('RT @LindaBanche: The universe is closer than you think A GIFT FROM THE STARS '
#  '#Regency #SF #PUYB #CR4U #IARTG https://t.co/YjaMIoCfX9 https:…')
# 'Mon Jul 11 03:00:55 +0000 2016'
#
# ('RT @Dena: "I can\'t breathe" chant #BlackLivesMatter protesters who took '
#  'over exit ramp in San Francisco https://t.co/moXgnJmio2')
# 'Mon Jul 11 03:01:10 +0000 2016'
#
# ('RT @LillyMaryPinto: 46 Terrorists killed with in 26 days in J&amp;K by RR , '
#  'SOG &amp; CRPF &amp; Para SF . Thanks to Indian Army.\n'
#  '#JaiHind https://t.co…')
# 'Mon Jul 11 03:01:11 +0000 2016'
#
# ('RT @SheHatesJacoby: Woahhhh RT @ArsalaiH: #Oakland (7/7/2016) Highway 880 '
#  'shutdown #AltonSterling #BlackLivesMatter https://t.co/SWb1mMNM2r')
# 'Mon Jul 11 03:01:11 +0000 2016'
#
# ('RT @Dena: "I can\'t breathe" chant #BlackLivesMatter protesters who took '
#  'over exit ramp in San Francisco https://t.co/moXgnJmio2')
# 'Mon Jul 11 03:01:12 +0000 2016'
#
# ('Berkeley City Council:  Erect Fence to Keep OUT Homeless—No Fence to Keep '
#  'out Illegal Aliens https://t.co/M10qwHzYvd')
# 'Mon Jul 11 03:01:14 +0000 2016'
#
# '@KDsIntellect outside of bay area, we all salty about the move as fans'
# 'Mon Jul 11 03:01:15 +0000 2016'
#
# 'hairs a mess @ Richmond, Virginia https://t.co/OTAnzj8Gq3'
# 'Mon Jul 11 03:01:16 +0000 2016'
#
# ('San Francisco Giants Car Truck SUV Motorcycle Trunk 3D Color Emblem '
#  'Instantly Customize Your Vehicle With This Brand https://t.co/rudriWIqMh')
# 'Mon Jul 11 03:01:16 +0000 2016'
#
# '@rubyrhu @boogbite Yeah, mine are just orange with black SF on them.'
# 'Mon Jul 11 03:01:20 +0000 2016'
#
# ('RT @A_S_Alexander: So many ways to show up! 26 Ways to Be in the Struggle '
#  'Beyond the Streets https://t.co/As2g4NMM3M #blacklivesmatter #mov…')
# 'Mon Jul 11 03:01:22 +0000 2016'
#
# 'This is a great list!  https://t.co/qOesewfErs'
# 'Mon Jul 11 03:01:24 +0000 2016'
#
# ('RT @ABC: Bay Area kidnapping victim remains missing even though 4 people '
#  'have been arrested in case. https://t.co/dPKsI6dWKG https://t.co/g…')
# 'Mon Jul 11 03:01:25 +0000 2016'
#
# ('Oh this hurts @rhda8386 I loved Frisco and then he left the show and they '
#  'trashed his character :( #GH https://t.co/c2jAWuYNr4')
# 'Mon Jul 11 03:01:25 +0000 2016'
#
# 'Never change, Internet #PokemonGO  https://t.co/dYPPQrc3gz'
# 'Mon Jul 11 03:01:26 +0000 2016'
#
# ('RT @prisonculture: Here are some good and useful suggestions. '
#  'https://t.co/s3XMDxVDE6')
# 'Mon Jul 11 03:01:30 +0000 2016'
#
# ("#Business Henrico's Livewire adds business unit to home technology services "
#  '- https://t.co/L3BgsBjrLF https://t.co/UasddWSHBc')
# 'Mon Jul 11 03:01:31 +0000 2016'
#
# ('Confederate Flag still has a presence in South Carolina '
#  'https://t.co/TzeLXViL3P #sf')
# 'Mon Jul 11 03:01:31 +0000 2016'
#
# ('@missmelodies how you gunna complain about the house wifi from Berkeley?! '
#  "2+2 ain't equaling 4 rn fam")
# 'Mon Jul 11 03:01:31 +0000 2016'
#
# ('RT @HitterNo: Madison Bumgarner of the San Francisco Giants has a no hitter '
#  'through the 5 inning')
# 'Mon Jul 11 03:01:31 +0000 2016'
#
# ('RT @AntiochTweets: The Bay Area has their own slang, yadadamean? '
#  'https://t.co/7ilhVnY7fp')
# 'Mon Jul 11 03:01:32 +0000 2016'
#
# "Antioch, Oakland hold vigils for those slain in week's violence  #news"
# 'Mon Jul 11 03:01:34 +0000 2016'
#
# ('RT @SouthLoneStar: Oakland PD Front Door.\n'
#  '#Blacklivesmatter are violent thugs. All PD should buy more robots to fight '
#  'them! https://t.co/SD…')
# 'Mon Jul 11 03:01:34 +0000 2016'
#
# ('RT @prisonculture: Here are some good and useful suggestions. '
#  'https://t.co/s3XMDxVDE6')
# 'Mon Jul 11 03:01:41 +0000 2016'
#
# "RT @kmichelle: Love y'all! 😘 https://t.co/7vrcxDHkzX"
# 'Mon Jul 11 03:01:42 +0000 2016'
#
# ("RT @cheapikeabot: Like new Ikea 'Malm' twin bed frame, box spring, and draws "
#  '(oakland lake merritt / grand) $200 https://t.co/OCnKJg9Ey4')
# 'Mon Jul 11 03:01:46 +0000 2016'
#
# ('Going over that #bridge 👌😊👍👏\n'
#  '#GoldenGate #SanFran #TheBay #PerfectDayForIt #SanFrancisco #travel… '
#  'https://t.co/QaZxIA6FJE')
# 'Mon Jul 11 03:01:47 +0000 2016'
#
# ('RT @prisonculture: Here are some good and useful suggestions. '
#  'https://t.co/s3XMDxVDE6')
# 'Mon Jul 11 03:01:49 +0000 2016'
#
# ('Our lucky charm is at the @SFGiants game! We love you in SF @Marlins_Man '
#  '❤️⚾️❤️⚾️❤️ https://t.co/mDbouVQNjj')
# 'Mon Jul 11 03:01:50 +0000 2016'
#
# '@Donnielover6 go back to when they were N Y Giants before SF.'
# 'Mon Jul 11 03:01:51 +0000 2016'
#
# ('https://t.co/5k4zr3yCcp #finance #economics https://t.co/duvSYdRebP\n'
#  '\n'
#  'why most of California’s coast remains unde… https://t.co/wNCrDhy0R0;')
# 'Mon Jul 11 03:01:52 +0000 2016'
#
# 'Report: Mutual interest between #Nets and UFA PF-SF Anthony Bennett.'
# 'Mon Jul 11 03:01:53 +0000 2016'
#
# ('@BryceRomagnoli @theScore @Casey_Hilderman @jaceyboyd I would like to '
#  'apologize to Mr. Bumgarner, the SF Giants, and to Get off my Johnson')
# 'Mon Jul 11 03:01:53 +0000 2016'
#
# ('And Now A Federal Officer Is Accused Of Trying To Pimp The Oakland... '
#  'https://t.co/Ull5QFPhfU')
# 'Mon Jul 11 03:01:54 +0000 2016'
#
# ('RT @prisonculture: Here are some good and useful suggestions. '
#  'https://t.co/s3XMDxVDE6')
# 'Mon Jul 11 03:01:55 +0000 2016'
#
# ("Giants' Bumgarner has no-hitter through 6 innings - SAN FRANCISCO (AP) -- "
#  'Madison Bumgarner has a no-hitter thr... https://t.co/bYBcoOERRy')
# 'Mon Jul 11 03:01:56 +0000 2016'
#
# ('RT @prisonculture: Here are some good and useful suggestions. '
#  'https://t.co/s3XMDxVDE6')
# 'Mon Jul 11 03:01:58 +0000 2016'
#
# ('RT @HistoryToLearn: Men building the San Francisco Bay Bridge, 1935. '
#  'https://t.co/Rh46ZM0x3V')
# 'Mon Jul 11 03:02:02 +0000 2016'
#
# ('iPhone 5S Case, Spigen® [Tough Armor] HEAVY DUTY [SF Smooth Black] EXTREME '
#  'Protection / Rugged but Slim Dual... https://t.co/UugizCXcah')
# 'Mon Jul 11 03:02:03 +0000 2016'
#
# ('RT @A_S_Alexander: So many ways to show up! 26 Ways to Be in the Struggle '
#  'Beyond the Streets https://t.co/As2g4NMM3M #blacklivesmatter #mov…')
# 'Mon Jul 11 03:02:04 +0000 2016'
#
# 'spent the whole day in sf playing pokemon go.'
# 'Mon Jul 11 03:02:05 +0000 2016'
#
# ('RT @pitbull: Thank you Bay Area for 16 years of love.#BadManTour '
#  '@princeroyce @FarrukoPR @shorelineamphitheatre @livenation #Dale https://t…')
# 'Mon Jul 11 03:02:07 +0000 2016'
#
# ("Antioch, Oakland hold vigils for those slain in week's violence: Vigils at "
#  'community centers and churches in… https://t.co/5QSeZk0dke')
# 'Mon Jul 11 03:02:10 +0000 2016'
#
# ('RT @nranews: Rep. Cedric Richmond (@RepRichmond) says #NRA doesn’t care '
#  'about black people. He should listen to Colion Noir: https://t.co/J…')
# 'Mon Jul 11 03:02:17 +0000 2016'
#
# ('Strong quake shakes coastal area in northwestern Ecuador - San Francisco '
#  'Chronicle https://t.co/tjRpDbQr4l')
# 'Mon Jul 11 03:02:17 +0000 2016'
#
# ("Baby K's first SF Giants game! #SFGiants #SFGHelloKitty "
#  'https://t.co/PoTlAp3BDS')
# 'Mon Jul 11 03:02:18 +0000 2016'
#
# 'Drove all the way to Oakland to eat pizza and watch naked and afraid lmao'
# 'Mon Jul 11 03:02:19 +0000 2016'
#
# ('On #BasicIncome: Oakland is trialling a universal basic income for all '
#  'https://t.co/z2dFRubz6y')
# 'Mon Jul 11 03:02:19 +0000 2016'
#
# ('RT @AditiJuneja3: And we thank you. We will change or perish together. '
#  '#BlackLivesMatter https://t.co/WO3at1BUYc')
# 'Mon Jul 11 03:02:20 +0000 2016'
#
# ('#Los #Angeles - #Grand #Canyon - San Francisco - Hawaii '
#  'https://t.co/iqn5BDaaoS')
# 'Mon Jul 11 03:02:22 +0000 2016'
#
# ('And the award for the best view of any Bay Area biergarten goes to... '
#  '#FactionBrewing🏆🍻👏🏼 #SeriouslyTho #ThatView https://t.co/yserrgjMVP')
# 'Mon Jul 11 03:02:20 +0000 2016'
#
# ('is this at the stonebriar mall in frisco what to heck lmaoooo '
#  'https://t.co/pTtFWzHRav')
# 'Mon Jul 11 03:02:22 +0000 2016'
#
# ('Giants Win!\n'
#  '\n'
#  'SF 4, AZ 0\n'
#  'FINAL\n'
#  '\n'
#  'Sweep! Sweep! Sweeping ourselves into the best record in baseball before the '
#  'break! https://t.co/JpzSGIMImV')
# 'Mon Jul 11 03:02:22 +0000 2016'
#
# ('RT @KianJcUpdates: Harrison joined the challenge | Richmond '
#  'https://t.co/c2vaT8DqyB')
# 'Mon Jul 11 03:02:23 +0000 2016'
#
# ("RT @AntiochTweets: This movie bouta be lit!! It's based in the Bay Area "
#  'https://t.co/rOW0fiWf1E')
# 'Mon Jul 11 03:02:25 +0000 2016'
#
# 'Water rights over the Berkeley Pit: A murky question https://t.co/fjvE2WNbHo'
# 'Mon Jul 11 03:02:25 +0000 2016'
#
# ('I liked a @YouTube video from @gymleadergeo https://t.co/8EP6EPecaN GBA '
#  'Season 6 Week 9 - San Francisco GiEnteis vs. Pittsburgh')
# 'Mon Jul 11 03:02:26 +0000 2016'
#
# ('#MadBum throws a complete game 1 hit shutout as @SFGiants win 4-0 to sweep '
#  'Arizona. 57 wins for SF. Predict 93 wins NL West. 36 to go...')
# 'Mon Jul 11 03:02:27 +0000 2016'
#
# ('Game over. Arizona Diamondbacks - 0, San Francisco Giants - 4. Go to '
#  'https://t.co/kCXKA0arPi to see results or watch a full repl')
# 'Mon Jul 11 03:02:31 +0000 2016'
#
# 'Sky @ Richmond Hill, Toronto Ontario Canada https://t.co/9Kpee79TYt'
# 'Mon Jul 11 03:02:32 +0000 2016'
#
# ('RT @TheJWittz: Pulling up into San Francisco, blessed be the lure droppers '
#  'https://t.co/m3t9jlqKNQ')
# 'Mon Jul 11 03:02:33 +0000 2016'
#
# 'Hot dang San Francisco. What mod you using. So pretty https://t.co/seNfriWqiK'
# 'Mon Jul 11 03:02:34 +0000 2016'
#
# ('RT @TakeMyTalent: Savion Flagg (2017/SF) #GMI2016 @__hvmble @HouDefenders '
#  '#takemytalent https://t.co/A1TMDEhP08')
# 'Mon Jul 11 03:02:35 +0000 2016'
#
# ('RT @bittergiantsfan: Giants Win!\n'
#  '\n'
#  'SF 4, AZ 0\n'
#  'FINAL\n'
#  '\n'
#  'Sweep! Sweep! Sweeping ourselves into the best record in baseball before the '
#  'break! htt…')
# 'Mon Jul 11 03:02:35 +0000 2016'
#
# ("FBI Director #Comey Says Hillary Committed Perjury But Loretta Lynch Won't "
#  'Charge Her https://t.co/HYqSZlvdDX...|sF')
# 'Mon Jul 11 03:02:35 +0000 2016'
#
# ('RT @AditiJuneja3: And we thank you. We will change or perish together. '
#  '#BlackLivesMatter https://t.co/WO3at1BUYc')
# 'Mon Jul 11 03:02:35 +0000 2016'
#
# ('Life can be quite good! 😉 #sanfrancisco #goldengatebridge @ San Francisco '
#  'Bay https://t.co/4CoquHKX5i')
# 'Mon Jul 11 03:02:37 +0000 2016'
#
# ('Strong quake shakes coastal area in northwestern Ecuador - San Francisco '
#  'Chronicle https://t.co/sIHv3X5UFj')
# 'Mon Jul 11 03:02:39 +0000 2016'
#
# ('RT @Ixora_xx: Pls rt 📣 SF : Night\n'
#  '📌Couple : #ฮยองกี้ #Hyungky\n'
#  '📌Rate :18+\n'
#  '📌Genre : AU\n'
#  '📌Link : https://t.co/8FVR8WfXEx https://t.co/7teDSwIhgF')
# 'Mon Jul 11 03:02:40 +0000 2016'
#
# ('RT @ABC: Bay Area kidnapping victim remains missing even though 4 people '
#  'have been arrested in case. https://t.co/dPKsI6dWKG https://t.co/g…')
# 'Mon Jul 11 03:02:44 +0000 2016'
#
# ('RT @bittergiantsfan: Giants Win!\n'
#  '\n'
#  'SF 4, AZ 0\n'
#  'FINAL\n'
#  '\n'
#  'Sweep! Sweep! Sweeping ourselves into the best record in baseball before the '
#  'break! htt…')
# 'Mon Jul 11 03:02:45 +0000 2016'
#
# ("RT @Classymotha: So glad you're a teacher at the university of Berkeley "
#  'California. \n'
#  ' https://t.co/bB3671nnvG')
# 'Mon Jul 11 03:02:45 +0000 2016'
#
# ("1956 Topps #26 San Francisco 49er's Teamcard! $20 Rare Vintage Football "
#  'Card! https://t.co/bqrWgyGiSb https://t.co/5f7PFCeK2l')
# 'Mon Jul 11 03:02:48 +0000 2016'
#
# ('RT @VipinINC: RPCC Chief Shri @SachinPilot will address #USIndiaConf as a '
#  'keynote speaker at UC Berkeley USA on 8th July. https://t.co/d46I…')
# 'Mon Jul 11 03:02:50 +0000 2016'
#
# ('1895 MAP OF SAN FRANCISCO Rand McNally Co Color Litho Engraving Large '
#  'Doublepage https://t.co/IifJTD2Pmj https://t.co/hAv36DHCye')
# 'Mon Jul 11 03:02:51 +0000 2016'
#
# "@YaVaJayJay_ at my house in Oakland I'm in the east"
# 'Mon Jul 11 03:02:52 +0000 2016'
#
# ('RT @bittergiantsfan: Giants Win!\n'
#  '\n'
#  'SF 4, AZ 0\n'
#  'FINAL\n'
#  '\n'
#  'Sweep! Sweep! Sweeping ourselves into the best record in baseball before the '
#  'break! htt…')
# 'Mon Jul 11 03:02:54 +0000 2016'
#
# ("RT @Oshianna2U: Foggy Night, Land's End\n"
#  'Fred Lyon #photography\n'
#  'San Francisco, 1953 https://t.co/lKhPBslHhd')
# 'Mon Jul 11 03:02:55 +0000 2016'
#
# ('RT @Dena: "I can\'t breathe" chant #BlackLivesMatter protesters who took '
#  'over exit ramp in San Francisco https://t.co/moXgnJmio2')
# 'Mon Jul 11 03:02:57 +0000 2016'
#
# "Bumgarner with the 1 hit shutout for the SF Giants 😍 he's an absolutely stud"
# 'Mon Jul 11 03:02:58 +0000 2016'
#
# ('RT @KianJcUpdates: Harrison joined the challenge | Richmond '
#  'https://t.co/c2vaT8DqyB')
# 'Mon Jul 11 03:02:59 +0000 2016'
#
# 'Live from SF Marriott Marquis!\n@marriottsf #kiosk https://t.co/mdLcF6LCQZ'
# 'Mon Jul 11 03:02:59 +0000 2016'
#
# ('Federer Escapes, Moves Into Wimbledon SF│ATP World Tour '
#  'https://t.co/SbN13fAywO')
# 'Mon Jul 11 03:03:01 +0000 2016'
#
# 'RT @helenantanova: today in San Francisco https://t.co/jd15sZVZPB'
# 'Mon Jul 11 03:03:02 +0000 2016'
#
# ('@curtisalvin @JrLuvsSports I wonder if Oakland would be attractive to '
#  'another NBA team to relocate to when the Warriors leave.')
# 'Mon Jul 11 03:03:02 +0000 2016'
#
# ("@nickmercier84 @NickJezak @hanranieri it's on Woodward in the Berkeley/Royal "
#  'Oak area 😁')
# 'Mon Jul 11 03:03:02 +0000 2016'
#
# ('RT @KianJcUpdates: Harrison joined the challenge | Richmond '
#  'https://t.co/c2vaT8DqyB')
# 'Mon Jul 11 03:03:03 +0000 2016'
#
# ('RT @ABC: Bay Area kidnapping victim remains missing even though 4 people '
#  'have been arrested in case. https://t.co/dPKsI6dWKG https://t.co/g…')
# 'Mon Jul 11 03:03:03 +0000 2016'
#
# ('SF vs Oakland through the lens of Kung Fu ...  Bruce Lee and the Early '
#  'Martial Arts Culture of San Francisco Bay https://t.co/2Rxn1r2oTq')
# 'Mon Jul 11 03:03:03 +0000 2016'
#
# ("@bhensley10 @beckstahhhh so I'm thinking copper still. Richmond. Next "
#  'Tuesday. Yes.')
# 'Mon Jul 11 03:03:04 +0000 2016'
#
# ('RT @bittergiantsfan: Giants Win!\n'
#  '\n'
#  'SF 4, AZ 0\n'
#  'FINAL\n'
#  '\n'
#  'Sweep! Sweep! Sweeping ourselves into the best record in baseball before the '
#  'break! htt…')
# 'Mon Jul 11 03:03:04 +0000 2016'
#
# ('FINAL: #SFGiants 4, #Dbacks 0 -- Tune into SportsNet Central on CSN Bay Area '
#  'for reaction: https://t.co/q3SZtNI8Ej https://t.co/jHSo9RuHWL')
# 'Mon Jul 11 03:03:05 +0000 2016'
#
# ('And with the best record in the majors at the break the San Francisco '
#  'Giants!!!! 57-33')
# 'Mon Jul 11 03:03:06 +0000 2016'
#
# ('TIX https://t.co/Y0pLFBS4O6 L (2) - San Fran #49ers vs Arizona Cards… '
#  'https://t.co/B7DMbOZkgG #Tickets #Ticket… https://t.co/o4J8qrW6uJ')
# 'Mon Jul 11 03:03:12 +0000 2016'
#
# 'Need team 94 sg and my friend a 92 sf both got goo iq  #2kfreeagent'
# 'Mon Jul 11 03:03:13 +0000 2016'
#
# ('Packed House as the City of Oakland came together tonight for Prayer!!! '
#  '#HealOakland https://t.co/KonDUO1rIe')
# 'Mon Jul 11 03:03:13 +0000 2016'
#
# ('RT @miaxtz_p: {SF} The Boy Upstairs Ch.3 \n'
#  '\n'
#  'Couple : #ทีมจินยองวอนพิล\n'
#  'TAG #ฟิคสสขป\n'
#  'For @ThenanTeuk\n'
#  'R-18\n'
#  '\n'
#  '☞(https://t.co/3K8KUNs4sD) https://…')
# 'Mon Jul 11 03:03:15 +0000 2016'
#
# ('RT @ArsalaiH: #Oakland (7/7/2016) Highway 880 shutdown #AltonSterling '
#  '#BlackLivesMatter https://t.co/Oal2wrhoyS')
# 'Mon Jul 11 03:03:16 +0000 2016'
#
# ('@SFGiants @bbelt9 @bcraw35 I would like to know how Belt and Crawford feel '
#  'about sharing this hashtag? Just curious, but I love u both ! #SF')
# 'Mon Jul 11 03:03:16 +0000 2016'
#
# ('RT @bittergiantsfan: Giants Win!\n'
#  '\n'
#  'SF 4, AZ 0\n'
#  'FINAL\n'
#  '\n'
#  'Sweep! Sweep! Sweeping ourselves into the best record in baseball before the '
#  'break! htt…')
# 'Mon Jul 11 03:03:16 +0000 2016'
#
# ('RT @MILVETERAN: Did Kashmiris expect SF to garland Burhan Wani ?They must '
#  'blame someone frm within for tipping off the SF.Bad Luck ! https:…')
# 'Mon Jul 11 03:03:17 +0000 2016'
#
# "I haven't seen Frisco friends in a year 😪 https://t.co/BwBAudcFKS"
# 'Mon Jul 11 03:03:17 +0000 2016'
#
# "Bumgarner with the 1 hit shutout for the SF Giants 😍 he's an absolute stud"
# 'Mon Jul 11 03:03:19 +0000 2016'
#
# 'RT @HarrisonWebb97: Richmond Virginia, is so beautiful &amp; peaceful.'
# 'Mon Jul 11 03:03:19 +0000 2016'
#
# ("these comments are filled with so much hatred &amp; misunderstanding!! It's "
#  'scary to think ppl actually feel this way. https://t.co/EW5WSAh956')
# 'Mon Jul 11 03:03:21 +0000 2016'
#
# ('Too bad for the D-Backs. They get swept in SF &amp; their unis look dirty '
#  "even when they're clean. #SFGiants")
# 'Mon Jul 11 03:03:21 +0000 2016'
#
# ('Only second time Giants in SF have gone into All-Star break in 1st place. '
#  "(First -- '93.)")
# 'Mon Jul 11 03:03:21 +0000 2016'
#
# ('THE SAN FRANCISCO GIANTS HAVE THE BEST RECORD IN BASEBALL HEADED INTO THE '
#  'ALL STAR BREAK')
# 'Mon Jul 11 03:03:22 +0000 2016'
#
# ('RT @A_S_Alexander: So many ways to show up! 26 Ways to Be in the Struggle '
#  'Beyond the Streets https://t.co/As2g4NMM3M #blacklivesmatter #mov…')
# 'Mon Jul 11 03:03:24 +0000 2016'
#
# ("Boom! Just cashed my first own 15* personal play on SF Runline. Admit I'm "
#  'new to capping my own games but saw a huge opportunity tonight')
# 'Mon Jul 11 03:03:25 +0000 2016'
#
# ('Berkeley is a magical city for Pokemon Go. Almost every corner has a '
#  'pokestop! #pokemongo')
# 'Mon Jul 11 03:03:26 +0000 2016'
#
# "One hit shutout for #MadBum - can't wait to get back out to SF"
# 'Mon Jul 11 03:03:26 +0000 2016'
#
# ('Oakland girls so damn hood, but we so damn pretty \n'
#  'sometimes a town just brings you down, but we feel no pity ❤')
# 'Mon Jul 11 03:03:27 +0000 2016'
#
# ('RT @bittergiantsfan: Giants Win!\n'
#  '\n'
#  'SF 4, AZ 0\n'
#  'FINAL\n'
#  '\n'
#  'Sweep! Sweep! Sweeping ourselves into the best record in baseball before the '
#  'break! htt…')
# 'Mon Jul 11 03:03:28 +0000 2016'
#
# ('@AndyStern_DC Andy: Good email to invite you to our UBI and A.I. panel in SF '
#  'in the fall? Will be moderated by Kara Swisher.')
# 'Mon Jul 11 03:03:28 +0000 2016'
#
# ("It's over in ARZ/SF...1 hitter, 1 BB, 14 K's for Bumgarner.  4-0 #SFGiants "
#  'win.')
# 'Mon Jul 11 03:03:31 +0000 2016'
#
# ('J Spades - Never Enough Ft Mist, Frisco 22, M Darrg   @REAL_JSPADES '
#  'https://t.co/lsb4cc2iMx')
# 'Mon Jul 11 03:03:34 +0000 2016'
#
# ('20414 Hidden Point Ln, Richmond, TX 77407, $209,900 4 beds, 2.5 baths '
#  'https://t.co/nk1CYPefEE')
# 'Mon Jul 11 03:03:34 +0000 2016'
#
# ('RT @mch7576: San Francisco Official Doubles Down: Fox News Is A ‘Propaganda '
#  'Machine, Nothing More And Nothing Less’ https://t.co/yXWme5mhP8@')
# 'Mon Jul 11 03:03:35 +0000 2016'
#
# ('527 Tara Plantation Dr, Richmond, TX 77469, $160,000 3 beds, 2 baths '
#  'https://t.co/xRrJfg1nm9')
# 'Mon Jul 11 03:03:35 +0000 2016'
#
# "Wouldn't be surprised if Bender ends up playing a lot of SF this season"
# 'Mon Jul 11 03:03:36 +0000 2016'
#
# ('Madison Bumgarner completes 1-hit masterpiece with 4-0 win over Arizona. 14 '
#  "K's. SF Giants enter the All-Star break with best record in MLB")
# 'Mon Jul 11 03:03:37 +0000 2016'
#
# ('RT @csoghoian: Is this evidence of gentrification? Kids from poor '
#  'neighborhoods are just as capable of writing essays about HTTPS. https://…')
# 'Mon Jul 11 03:03:39 +0000 2016'
#
# ('I added a video to a @YouTube playlist https://t.co/sZXcDBoSp0 Cafe | La '
#  'Promenade Café | Coffee | San Francisco | Review | Content')
# 'Mon Jul 11 03:03:40 +0000 2016'
#
# '@SFGiants Best in MLB at the break, Congrats SF Giants, this is our year.'
# 'Mon Jul 11 03:03:42 +0000 2016'
#
# ("@ihateABS you know what's going on up here. Lots of good, some bad, mostly "
#  "hipsters. How's SF?")
# 'Mon Jul 11 03:03:43 +0000 2016'
#
# ('RT @_TYTY0618: ❥ [SF] SILENCE (1/2)\n'
#  '❥ https://t.co/Ua38y6airx \n'
#  '❥ #fichellolove\n'
#  '(pls rt) @BEATandSOUND https://t.co/gcVuJkRkyr')
# 'Mon Jul 11 03:03:43 +0000 2016'
#
# ("don't forget Detroit. We had a peaceful protest Friday night and so did "
#  'Atlanta. #UnitedWeStand✊🏾 https://t.co/LQ6PPTM7kv')
# 'Mon Jul 11 03:03:47 +0000 2016'
#
# ('OH NO.\n'
#  '\n'
#  'NO, NO, NO. \n'
#  '\n'
#  "Richmond's night market is dinosaur themed this year.\n"
#  '\n'
#  '😭💖😭💖😭💖😭💖😭💖 https://t.co/sBnyL2HN9E')
# 'Mon Jul 11 03:03:47 +0000 2016'
#
# ('RT @Dena: "I can\'t breathe" chant #BlackLivesMatter protesters who took '
#  'over exit ramp in San Francisco https://t.co/moXgnJmio2')
# 'Mon Jul 11 03:03:50 +0000 2016'
#
# ("Bum is a beast don't get me wrong but Posey needs more credit for this "
#  'invincible pitching staff in San Fran')
# 'Mon Jul 11 03:03:51 +0000 2016'
#
# ("This is one amazing pie! I'm so happy I brought it to Kansas from San "
#  "Francisco's @missionpie https://t.co/87Y6ED2LPy")
# 'Mon Jul 11 03:03:52 +0000 2016'
#
# ('"Eboni, what even are your accomplishments anymore?" \n'
#  'Political statements at 4am.\n'
#  'Getting a favourite from SF.\n'
#  'World domination.\n'
#  'The usual.')
# 'Mon Jul 11 03:03:52 +0000 2016'
#
# ("Giants' Bumgarner loses no-hitter after 7 1/3 innings: SAN FRANCISCO (AP) — "
#  'Giants left-hander Madison Bumgar... https://t.co/Ay3QrDgodo')
# 'Mon Jul 11 03:03:52 +0000 2016'
#
# 'Hell YES! #MadBum https://t.co/8oj1mfvF5d'
# 'Mon Jul 11 03:03:53 +0000 2016'
#
# ('Giants win #57 behind a MadBum gem!!! The San Francisco Giants are the best '
#  'team in baseball heading into the All-Star Break.')
# 'Mon Jul 11 03:03:55 +0000 2016'
#
# ('DVDs a?vail now at Walmart!! Get your copies now!!!  #walmart #newrelease @ '
#  'San Francisco Bay https://t.co/AI50qZSnO3')
# 'Mon Jul 11 03:03:55 +0000 2016'
#
# ("It's a final in San Francisco. The #SFGiants beat the #DBacks 4-0. Madison "
#  'Bumgarner threw a complete game shutout with 14 Ks &amp; just 1 hit.')
# 'Mon Jul 11 03:03:56 +0000 2016'
#
# ('God sent me to Richmond FCA camp all last week for the healing in my foot to '
#  'be complete!!! #RiseUp')
# 'Mon Jul 11 03:03:57 +0000 2016'
#
# '@QiasOmar throw me a follow fam and can you not make SF tbd'
# 'Mon Jul 11 03:03:57 +0000 2016'
#
# ('Madison Bumgarner pitched one hell of a game for the SF Giants... gets the '
#  'win and only allowed 1 hit total! Impressive')
# 'Mon Jul 11 03:03:57 +0000 2016'
#
# ('@realDonaldTrump @HillaryClinton Fugitive sex offenders included on '
#  "McAuliffe's rights restoration list https://t.co/RJQyAb4Ej2")
# 'Mon Jul 11 03:03:58 +0000 2016'
#
# ("RT @PeachesChrist: It's COMING to SF darlin's... After a giant, successful "
#  'run in New York City, the West Coast… https://t.co/t7XYQuNXQU')
# 'Mon Jul 11 03:03:58 +0000 2016'
#
# ('RT @A_S_Alexander: So many ways to show up! 26 Ways to Be in the Struggle '
#  'Beyond the Streets https://t.co/As2g4NMM3M #blacklivesmatter #mov…')
# 'Mon Jul 11 03:03:58 +0000 2016'
#
# ('Madison Bumgarner - San Francisco Giants: Win, CG 9 IPs, 1 hit, 14 Ks, 1 BB '
#  '[FD(81) DK(56.05)]')
# 'Mon Jul 11 03:04:01 +0000 2016'
#
# ('So many tournaments on Saturday! Marvel, SF ofc, but also SCV... maybe even '
#  'that free KOF? Gaaahhh.')
# 'Mon Jul 11 03:04:01 +0000 2016'
#
# 'Madison Bumgarner - San Francisco Giants: Win, CG 9 IPs, 1 hit, 14 Ks, 1 BB'
# 'Mon Jul 11 03:04:01 +0000 2016'
#
# ('2018 SF Versailles Justin Ahrens has received offer from Oakland University, '
#  'and Miami Ohio University https://t.co/kGWT7IHOR6')
# 'Mon Jul 11 03:04:02 +0000 2016'
#
# ('@alchemistbeer Focal Banger and @SFGiants win! Great night! #MadBum #SF '
#  '#craftbeer #Montreal #Vermont #Giants https://t.co/nwZpkQ6BQD')
# 'Mon Jul 11 03:04:05 +0000 2016'
#
# ('RT @WORLDSTAR: 1000+ Protesters take over  I-880 in Oakland... 👀 '
#  'https://t.co/R9Uhjmhq3T')
# 'Mon Jul 11 03:04:06 +0000 2016'
#
# ('San Francisco Says Final Farewell To Kaepernick (28) – But Is This Really '
#  'The End? | Gossip Story https://t.co/K5pGkGeqAx')
# 'Mon Jul 11 03:04:10 +0000 2016'
#
# ('[MLB: Athletics] Healy goes 2-for-3 for U.S. in Futures Game '
#  'https://t.co/DrcvVW0SjW #Athletics')
# 'Mon Jul 11 03:04:11 +0000 2016'
#
# ('[Sports Illustrated] Madison Bumgarner loses no-hitter in eighth '
#  'https://t.co/cFfXz9VTHR #SFGiants')
# 'Mon Jul 11 03:04:12 +0000 2016'
#
# ('[NBC Sports: Hardball Talk] Yoan Moncada named MVP of the Futures Game '
#  'https://t.co/fkqNheXwxp #SFGiants')
# 'Mon Jul 11 03:04:12 +0000 2016'
#
# ('A tree grows in Staten Island. A -Callery Pear at  292 Port Richmond Avenue, '
#  'to be specific. https://t.co/M7AQi42jKh')
# 'Mon Jul 11 03:04:13 +0000 2016'
#
# 'Bay area is dominant, @SFGiants @warriors.'
# 'Mon Jul 11 03:04:14 +0000 2016'
#
# '#SFGiants SWEEEEEEEP!!!  &amp; Shutout!!! 4-0 SF'
# 'Mon Jul 11 03:04:15 +0000 2016'
#
# ('@dcsportsfan6 the Bay Area has ONE basketball team sweetheart. The warriors '
#  'are moving to SF in 2 years. But the bay only has 1 NBA team.')
# 'Mon Jul 11 03:04:15 +0000 2016'
#
# ('Sidenote:\n'
#  'The Bay Area sure has been in the spotlight. Olympic Gymnastics trials on '
#  'top of the Warriors, Giants, and Sharks? #YayAreaaaaaaaa')
# 'Mon Jul 11 03:04:19 +0000 2016'
#
# 'RT @jwalkthisway: Proud of this young fella @__hvmble  https://t.co/Ml4ncCHAR3'
# 'Mon Jul 11 03:04:22 +0000 2016'
#
# ('RT @MessiWorId: Spain lost to Italy in round of 16\n'
#  'Italy lost to Germany in QF\n'
#  'Germany lost to France in SF\n'
#  '\n'
#  'And in the end Portugal beat F…')
# 'Mon Jul 11 03:04:24 +0000 2016'
#
# ('RT @MarieMMao: @MadoreBaess Tour ✈️ \n'
#  'July 16 sneakerpopup - Treasure Island SF w| anthems_designs \n'
#  'July 30… https://t.co/Kp5fvPInQl')
# 'Mon Jul 11 03:04:25 +0000 2016'
#
# ("@KSJ49 Had he done so, it would have broken the record for most K's in a "
#  'game by a Giants pitcher EVER. Not just SF, but going back to NY')
# 'Mon Jul 11 03:04:26 +0000 2016'
#
# ('RT @A_S_Alexander: So many ways to show up! 26 Ways to Be in the Struggle '
#  'Beyond the Streets https://t.co/As2g4NMM3M #blacklivesmatter #mov…')
# 'Mon Jul 11 03:04:28 +0000 2016'
#
# 'yellow day sa college, sf sa hs https://t.co/nfEHs5J0uD'
# 'Mon Jul 11 03:04:29 +0000 2016'
#
# ("RT @FAN590: It's a final in San Francisco. The #SFGiants beat the #DBacks "
#  '4-0. Madison Bumgarner threw a complete game shutout with 14 Ks &amp;…')
# 'Mon Jul 11 03:04:30 +0000 2016'
#
# ('@chancetherapper has a #coloringbookworldtour date in SF on my birthday sold '
#  'out 😢')
# 'Mon Jul 11 03:04:31 +0000 2016'
#
# 'walking around San Francisco playing Pokemon go :)'
# 'Mon Jul 11 03:04:32 +0000 2016'
#
# 'Loving this. Very proactive community work. https://t.co/bvuHV20vcQ'
# 'Mon Jul 11 03:04:32 +0000 2016'
#
# ('RT @SpecialKay00: At the Oakland 880 protest I was on the front line '
#  'reminding all the "white allies" that if they were serious they\'d be o…')
# 'Mon Jul 11 03:04:33 +0000 2016'
#
# ('ASSOCIATE FOR RESEARCH INVESTMENT (Education Coordinator II) job in '
#  'Richmond, VA (23219) - Richmon... https://t.co/4YCmWJx7rQ via @todmassa')
# 'Mon Jul 11 03:04:33 +0000 2016'
#
# 'celebrating San Francisco Giants win'
# 'Mon Jul 11 03:04:35 +0000 2016'
#
# ('#MLB Rare. Vintage Oakland A\'s #Athletics MLB 3" Patch. L@@k. No Reserve. '
#  'https://t.co/2PSFm5YHRz #Baseball https://t.co/0gA77R5YuR')
# 'Mon Jul 11 03:04:35 +0000 2016'
#
# ('#MLB Yoenis Cespedes Oakland #Athletics #Jersey Gold SGA XL New Mets '
#  'https://t.co/VpJbzyA8I3 #Baseball https://t.co/RFT8dERHiH')
# 'Mon Jul 11 03:04:36 +0000 2016'
#
# ('#Sporting #Goods San Francisco #Giants authentic #Jersey World Series 2012 '
#  '#Baseball size… https://t.co/TzqMKfwrUL https://t.co/Qm6VcrzOyL')
# 'Mon Jul 11 03:04:36 +0000 2016'
#
# ('Men\'s Oakland A\'s "Property Of Oakland #Athletics" Yellow T-Shirt sz Large '
#  'https://t.co/aXvMIP2hjA #Sports #Goods https://t.co/jmKeUuYmvc')
# 'Mon Jul 11 03:04:36 +0000 2016'
#
# ('RT @KianJcUpdates: KnJ with fans in Richmond! #DontTryThisAtHomeTour '
#  'https://t.co/1FD6d54n0l')
# 'Mon Jul 11 03:04:38 +0000 2016'
#
# ('Final: Giants 4 Diamondbacks 0. WP: SF M Bumgarner (10-4) LP: ARI A Bradley '
#  '(3-5)via @ESPN App https://t.co/9uKzZ1798n')
# 'Mon Jul 11 03:04:38 +0000 2016'
#
# ("#Sport #Buzz RARE Vintage ORIGINAL 1980 Oakland A's Starter Jacket, Small - "
#  'NEVER WORN! https://t.co/iGchlfUL8I https://t.co/RwmqSQychS')
# 'Mon Jul 11 03:04:38 +0000 2016'
#
# '@dzjane_ We miss you guys too 😢 you better FaceTime with me once u get to SF'
# 'Mon Jul 11 03:04:38 +0000 2016'
#
# ('RT @angbeees: Our lucky charm is at the @SFGiants game! We love you in SF '
#  '@Marlins_Man ❤️⚾️❤️⚾️❤️ https://t.co/mDbouVQNjj')
# 'Mon Jul 11 03:04:39 +0000 2016'
#
# ('#SFGiants  with best record at the Break for only 2nd time in SF history '
#  '...the other, 1993 .')
# 'Mon Jul 11 03:04:40 +0000 2016'
#
# ('RT @FakeSportsCentr: The Golden State Warriors are the new Full House in the '
#  'Bay Area... 😎\n'
#  '\n'
#  'Via - @bycycle \n'
#  '\n'
#  'https://t.co/RWVMoUj1mY')
# 'Mon Jul 11 03:04:40 +0000 2016'
#
# 'Not a bad time to be a sports fan in the Bay Area.'
# 'Mon Jul 11 03:04:40 +0000 2016'
#
# ('For the Future of San Francisco Bay Area Real Estate, an Eventful Week | '
#  'California Realtor® Alfredo Capalad Jr. https://t.co/nJAUjIAAQV')
# 'Mon Jul 11 03:04:42 +0000 2016'
#
# 'FINAL MLB: ARI 0 vs SF 4 - via @ESPN App https://t.co/Iov0b73ZL7'
# 'Mon Jul 11 03:04:42 +0000 2016'
#
# ("RT @soledadobrien: 1. Here's a story from 1995. My first reporting gig in "
#  'SF. I live in Oakland and cover Oakland but on this day I am in o…')
# 'Mon Jul 11 03:04:42 +0000 2016'
#
# 'RT @hummingbird0088: #SFGiants SWEEEEEEEP!!!  &amp; Shutout!!! 4-0 SF'
# 'Mon Jul 11 03:04:43 +0000 2016'
#
# ('Heading back to London in an hour.\n'
#  "Thanks, San Francisco. It's been a thing.\n"
#  '\n'
#  'Thanks @CAYLLLES for being such a good host too. You suck ✨')
# 'Mon Jul 11 03:04:43 +0000 2016'
#
# ("Mitch Woods &amp; His Rocket 88's @mappinings #thingstodo #SanFrancisco "
#  '#music #today https://t.co/6t6Gd0xY2s')
# 'Mon Jul 11 03:04:43 +0000 2016'
#
# ('RT @pmarca: Cause and effect strike again! Fewer buses = more cars. '
#  'https://t.co/3nJsMV2m7o')
# 'Mon Jul 11 03:04:44 +0000 2016'
#
# ('Madison Bumgarner just put the rest of the NL on notice. The road to the '
#  'series goes through San Francisco')
# 'Mon Jul 11 03:04:46 +0000 2016'
#
# ('RT @CelticsHub: Current Nets depth chart: \n'
#  'PG: Lin, Levert\n'
#  'SG: Bogdanovic\n'
#  'SF: Hollis-Jefferson, Kilpatrick\n'
#  'PF: Booker, McCullough\n'
#  'C: Lopez,…')
# 'Mon Jul 11 03:04:46 +0000 2016'
#
# ('@TudalWineryNapa - Booke flight to SF from Chicago for Oct 1 visit to the '
#  'winery based on info from the wine club.  Is that the right date?')
# 'Mon Jul 11 03:04:46 +0000 2016'
#
# ('RT @DeanDobbs: Heading back to London in an hour.\n'
#  "Thanks, San Francisco. It's been a thing.\n"
#  '\n'
#  'Thanks @CAYLLLES for being such a good host to…')
# 'Mon Jul 11 03:04:48 +0000 2016'
#
# ('RT @_wingoals: THE SAN FRANCISCO GIANTS HAVE THE BEST RECORD IN BASEBALL '
#  'HEADED INTO THE ALL STAR BREAK')
# 'Mon Jul 11 03:04:48 +0000 2016'
#
# ('RT @soledadobrien: 2. One of the major bridges in SF is closed requiring all '
#  'of the executives who live in Marin (and that direction) to dr…')
# 'Mon Jul 11 03:04:48 +0000 2016'
#
# 'THE TWO BAY AREA SHORTSTOPS GOT SNUBBED'
# 'Mon Jul 11 03:04:49 +0000 2016'
#
# ('SF wine distributor tells me he is much happier now because electric bike '
#  'replaced car https://t.co/DVtoda1oB2')
# 'Mon Jul 11 03:04:49 +0000 2016'
#
# 'Finna get to east Oakland and play Pokemon Go'
# 'Mon Jul 11 03:04:51 +0000 2016'
#
# ('From the north vista point 👍👌😊☀️\n'
#  '#GoldenGate #bridge #SanFran #PerfectDayForIt #travel… '
#  'https://t.co/BaC9t84tTT')
# 'Mon Jul 11 03:04:52 +0000 2016'
#
# ('RT @_TYTY0618: ❥ [SF] SILENCE (1/2)\n'
#  '❥ https://t.co/Ua38y6airx \n'
#  '❥ #fichellolove\n'
#  '(pls rt) @BEATandSOUND https://t.co/gcVuJkRkyr')
# 'Mon Jul 11 03:04:53 +0000 2016'
#
# ('RT @DeanDobbs: Heading back to London in an hour.\n'
#  "Thanks, San Francisco. It's been a thing.\n"
#  '\n'
#  'Thanks @CAYLLLES for being such a good host to…')
# 'Mon Jul 11 03:04:53 +0000 2016'
#
# ('San Francisco Party Bus to Diana Ross at Mountain Winery @mappinings '
#  '#thingstodo #SanFrancisco #music #today https://t.co/mCxPxYOxjv')
# 'Mon Jul 11 03:04:54 +0000 2016'
#
# 'Oakland #Raiders Ladies Medium Jacket https://t.co/CPjtMipmrT #NFL #Football'
# 'Mon Jul 11 03:04:54 +0000 2016'
#
# ('RT @LindaBanche: The universe is closer than you think A GIFT FROM THE STARS '
#  '#Regency #SF #PUYB #CR4U #IARTG https://t.co/YjaMIoCfX9 https:…')
# 'Mon Jul 11 03:04:53 +0000 2016'
#
# ('RT @soledadobrien: 3.  So they can come to work. Even though they make '
#  'decisions every day re: how we cover Oakland (and elsewhere) the bul…')
# 'Mon Jul 11 03:04:54 +0000 2016'
#
# ('RT @30SecBasebaIl: The Bay Area has yet another good outside shooter  '
#  'https://t.co/YGxfl2PbFS')
# 'Mon Jul 11 03:04:55 +0000 2016'
#
# ('RT @A_S_Alexander: So many ways to show up! 26 Ways to Be in the Struggle '
#  'Beyond the Streets https://t.co/As2g4NMM3M #blacklivesmatter #mov…')
# 'Mon Jul 11 03:04:56 +0000 2016'
#
# ('1000 Man March in Richmond next weekend, definitely tryna be out there for '
#  'that! #BlackLivesMatter #RVA')
# 'Mon Jul 11 03:04:56 +0000 2016'
#
# ('#NFL #49ers Nike NFL San Francisco 49ers Stadium Gloves Size 2XL '
#  'https://t.co/IMtlUeGwgo #FootBall #Bargains https://t.co/2B1cGk2J8Q')
# 'Mon Jul 11 03:04:56 +0000 2016'
#
# ('#MLB #Baseball San Francisco #Giants authentic #Jersey World Series 2012… '
#  'https://t.co/X2aZqChhEE #Sporting #Goods https://t.co/uRNQwlW1K7')
# 'Mon Jul 11 03:04:56 +0000 2016'
#
# ('#Collectibles #Buzz Nike #NFL San Francisco #49ers Stadium Gloves Size 2XL '
#  'https://t.co/5tjX17GWbZ #onsale #Discount https://t.co/X7O2v4s8sp')
# 'Mon Jul 11 03:04:57 +0000 2016'
#
# ('RT @MessiWorId: Spain lost to Italy in round of 16\n'
#  'Italy lost to Germany in QF\n'
#  'Germany lost to France in SF\n'
#  '\n'
#  'And in the end Portugal beat F…')
# 'Mon Jul 11 03:04:58 +0000 2016'
#
# "Don't wanna jinx nothing but the SF Giants parade gonna be lit this year"
# 'Mon Jul 11 03:04:58 +0000 2016'
#
# 'Final Arizona Diamondbacks 0-4 San Francisco Giants. San Francisco Giants Win'
# 'Mon Jul 11 03:04:59 +0000 2016'
#
# ('Vintage Adidas Oakland #Raiders Charles Woodson screened #Jersey Youth… '
#  'https://t.co/66NnrNjcMW #Sporting #Goods https://t.co/n6WvqMZtqz')
# 'Mon Jul 11 03:04:59 +0000 2016'
#
# ('RT @MLBTopPerformer: Madison Bumgarner - San Francisco Giants: Win, CG 9 '
#  'IPs, 1 hit, 14 Ks, 1 BB [FD(81) DK(56.05)]')
# 'Mon Jul 11 03:04:59 +0000 2016'
#
# ('RT @LillyMaryPinto: 46 Terrorists killed with in 26 days in J&amp;K by RR , '
#  'SOG &amp; CRPF &amp; Para SF . Thanks to Indian Army.\n'
#  '#JaiHind https://t.co…')
# 'Mon Jul 11 03:05:00 +0000 2016'
#
# ('As drive-by efforts go, the @Dbacks drive-by tonight at SF was exceptional. '
#  '#Giants 4 #Dbacks 0.')
# 'Mon Jul 11 03:05:00 +0000 2016'
#
# ('@ebbtideapp Tide in Oakland Inner Harbor, California 07/11/2016\n'
#  ' Low 12:13am  2.0\n'
#  'High  5:38am  4.5\n'
#  ' Low 11:47am  1.3\n'
#  'High  6:42pm  6.0')
# 'Mon Jul 11 03:05:00 +0000 2016'
#
# ('20 of the best San Francisco airbnb rentals https://t.co/uhT2Iayih8 '
#  'https://t.co/CRKGH3BESu')
# 'Mon Jul 11 03:05:02 +0000 2016'
#
# ("So I'm curious... how many people live in Richmond, Virginia? I just moved "
#  'here would be lit to meet some new people :)')
# 'Mon Jul 11 03:05:03 +0000 2016'
#
# ('RT @UCBerkeley: UC Berkeley admit class includes 1K more Californians '
#  'https://t.co/4a9FW2rcGU #highered https://t.co/xLgzDZcMtV')
# 'Mon Jul 11 03:05:06 +0000 2016'
#
# ('SF 94/Ap 10/Kp 2/Spots 46 07/10/2016/#Solar Wind 550 km/s Bz: 2016 Jul 11 '
#  '0300Z at -2.6 nT #spaceweather #suninfo')
# 'Mon Jul 11 03:05:07 +0000 2016'
#
# ('RT @DeanDobbs: Heading back to London in an hour.\n'
#  "Thanks, San Francisco. It's been a thing.\n"
#  '\n'
#  'Thanks @CAYLLLES for being such a good host to…')
# 'Mon Jul 11 03:05:07 +0000 2016'
#
# ('@FieldEcology @HerpMapper Cool. But. The disappearance of most herps from '
#  'Bay Area is an ongoing source of sadness...')
# 'Mon Jul 11 03:05:07 +0000 2016'
#
# ...
#
# ('RT @soledadobrien: 6. Obvious bias about Oakland signifies maybe the way '
#  'they think about stories out of O will also be biased. It is my fi…')
# 'Mon Jul 11 03:05:48 +0000 2016'
#
# ("RT @LiveDoppler7HD: It'll be sunny in parts of the Bay Area tomorrow. WATCH "
#  '@DrewTumaABC7 AccuWeather forecast: https://t.co/HdtZvxJQuJ htt…')
# 'Mon Jul 11 03:05:49 +0000 2016'
#
# ('Baumgartner is the bomb! — watching Arizona Diamondbacks vs San Francisco '
#  'Giants')
# 'Mon Jul 11 03:05:52 +0000 2016'
#
# ('SF offers rare signing bonuses amid big teacher shortage... '
#  'https://t.co/Locgyb8Jxx')
# 'Mon Jul 11 03:05:52 +0000 2016'
#
# ('RT @LindaBanche: The universe is closer than you think A GIFT FROM THE STARS '
#  '#Regency #SF #PUYB #CR4U #IARTG https://t.co/YjaMIoCfX9 https:…')
# 'Mon Jul 11 03:05:52 +0000 2016'
#
# ('RT @prisonculture: Here are some good and useful suggestions. '
#  'https://t.co/s3XMDxVDE6')
# 'Mon Jul 11 03:05:54 +0000 2016'
#
# 'Remember this? https://t.co/waBwEIZpe8'
# 'Mon Jul 11 03:05:54 +0000 2016'
#
# ('RT @codypooch: Richmond Mayor the Hon. Dwight C. Jones: Tell Sister City, '
#  'Uijeongbu, South Korea, That We’re Opposed... https://t.co/6Zf3fH…')
# 'Mon Jul 11 03:05:55 +0000 2016'
#
# ("RT @xShorbie: So I'm curious... how many people live in Richmond, Virginia? "
#  'I just moved here would be lit to meet some new people :)')
# 'Mon Jul 11 03:05:56 +0000 2016'
#
# ('RT @yoshi6755: @nicoletteannmc Hopefully someone can answer me when will it '
#  'be showing here in SF?? No one seems to care to tell. Haaayy #A…')
# 'Mon Jul 11 03:05:57 +0000 2016'
#
# ('RT @prisonculture: Here are some good and useful suggestions. '
#  'https://t.co/s3XMDxVDE6')
# 'Mon Jul 11 03:05:58 +0000 2016'
#
# ('July 10, 2016 at 11:05PM SIGN #WARRIORS NO #SF MISSION BAY ARENA Petition '
#  'https://t.co/5jmC9F3em8')
# 'Mon Jul 11 03:05:58 +0000 2016'
#
# ('RT @soledadobrien: 8.  I mention the obvious: I live in Oakland and drive '
#  'into the office in SF almost every day.')
# 'Mon Jul 11 03:05:59 +0000 2016'
#
# 'RT @jwalkthisway: Proud of this young fella @__hvmble  https://t.co/Ml4ncCHAR3'
# 'Mon Jul 11 03:05:59 +0000 2016'
#
# ('RT @AntiochTweets: How people from the Bay Area be at weddings: '
#  'https://t.co/XVdMI4YGgx')
# 'Mon Jul 11 03:06:01 +0000 2016'
#
# ('RT @LindaBanche: The universe is closer than you think A GIFT FROM THE STARS '
#  '#Regency #SF #PUYB #CR4U #IARTG https://t.co/YjaMIoCfX9 https:…')
# 'Mon Jul 11 03:06:01 +0000 2016'
#
# ("RT @Oshianna2U: Foggy Night, Land's End\n"
#  'Fred Lyon #photography\n'
#  'San Francisco, 1953 https://t.co/lKhPBslHhd')
# 'Mon Jul 11 03:06:01 +0000 2016'
#
# ("RT @xShorbie: So I'm curious... how many people live in Richmond, Virginia? "
#  'I just moved here would be lit to meet some new people :)')
# 'Mon Jul 11 03:06:02 +0000 2016'
#
# ('3-Methylpentane (1.76 PPB) detected above threshold ( &gt;0.0 PPB) @ '
#  'Richmond: Atchison Village Area - Community Location - 2016-07-10 20:06:02')
# 'Mon Jul 11 03:06:03 +0000 2016'
#
# ('@rocksmoulder @JimBlackMax @BernieHQuillson Hit up my bay area pager, boy! '
#  '143*69*911')
# 'Mon Jul 11 03:06:03 +0000 2016'
#
# ('RT @SiaranBolaLivee: #POR 1-1 #ISL \n'
#  '#POR 0-0 #AUT \n'
#  '#POR 3-3 #HUN \n'
#  '16 #CRO 0-1 #POR \n'
#  'QF #POL 1-1 #POR *\n'
#  'SF #POR 2-0 #WAL \n'
#  'F #POR 1-0 #FRA ht…')
# 'Mon Jul 11 03:06:03 +0000 2016'
#
# ('RT @giantsfan706: @SFGiants Best in MLB at the break, Congrats SF Giants, '
#  'this is our year.')
# 'Mon Jul 11 03:06:05 +0000 2016'
#
# 'RT @ab_grafix: Remember this? https://t.co/waBwEIZpe8'
# 'Mon Jul 11 03:06:05 +0000 2016'
#
# 'RT @back2blackmgc: yellow day sa college, sf sa hs https://t.co/nfEHs5J0uD'
# 'Mon Jul 11 03:06:05 +0000 2016'
#
# 'seeing this surfer hippie go through SF selection makes me cringe so hard'
# 'Mon Jul 11 03:06:06 +0000 2016'
#
# ('PG- Dennis\n'
#  'SG- Baze\n'
#  'SF- Prince\n'
#  'PF- Millsap\n'
#  'C- Howard https://t.co/A4wenvGf57')
# 'Mon Jul 11 03:06:06 +0000 2016'
#
# ('MLB 7/10/16\n'
#  'Col O12.5 💰⚾️💰\n'
#  'Tor O9.5 👎🏼\n'
#  'SF -1.5 💰⚾️💰\n'
#  'Mia ML 💰⚾️💰\n'
#  'Tex ML 👎🏼\n'
#  'STL ML 💰⚾️💰\n'
#  '\n'
#  '4-2 at +$183\n'
#  '\n'
#  'Week\n'
#  '34-25-3 at +$836\n'
#  '\n'
#  '#CappingMinds')
# 'Mon Jul 11 03:06:07 +0000 2016'
#
# ("RT @NRA: What the terrorism watch list is...and isn't "
#  'https://t.co/DcWaE5sPwi #2A')
# 'Mon Jul 11 03:06:07 +0000 2016'
#
# 'bay area OR socal https://t.co/oMVDt1Cl7R'
# 'Mon Jul 11 03:06:07 +0000 2016'
#
# 'This look like the frisco mall... https://t.co/dvlGBjbLJJ'
# 'Mon Jul 11 03:06:08 +0000 2016'
#
# ('RT @AntiochTweets: How people from the Bay Area be at weddings: '
#  'https://t.co/XVdMI4YGgx')
# 'Mon Jul 11 03:06:11 +0000 2016'
#
# 'Sacramento, white water rafting, and San Fran trip📍😜 https://t.co/dVys2kHM7M'
# 'Mon Jul 11 03:06:10 +0000 2016'
#
# ('RT @Karnythia: Florida cops have been caught planting drugs, shaking down '
#  'business owners, running drugs...Oakland police...group sexual ab…')
# 'Mon Jul 11 03:06:12 +0000 2016'
#
# 'Bay Area surgeons are requesting consults with Madbum tonight!'
# 'Mon Jul 11 03:06:12 +0000 2016'
#
# ('RT @prisonculture: Here are some good and useful suggestions. '
#  'https://t.co/s3XMDxVDE6')
# 'Mon Jul 11 03:06:13 +0000 2016'
#
# ("I'm rootin for Dallas Philadelphia Oakland and Cincinnati this next football "
#  'season @RAIDERS @Eagles @dallascowboys @Bengals')
# 'Mon Jul 11 03:06:14 +0000 2016'
#
# 'RT @HarrisonWebb97: Richmond Virginia, is so beautiful &amp; peaceful.'
# 'Mon Jul 11 03:06:14 +0000 2016'
#
# ('July 10, 2016 at 11:06PM Dante Fowler talks Oakland #Raiders at #NFLDraft '
#  'https://t.co/EkNc056bXw')
# 'Mon Jul 11 03:06:15 +0000 2016'
#
# ('RT @hfradiospacewx: SF 94/Ap 10/Kp 2/Spots 46 07/10/2016/#Solar Wind 550 '
#  'km/s Bz: 2016 Jul 11 0300Z at -2.6 nT #spaceweather #suninfo')
# 'Mon Jul 11 03:06:16 +0000 2016'
#
# ('@darkwaveduchess owes me for like having 21+ shows and missing Oakland so I '
#  'couldnt see her and @LuiDiamonds is already my ninja so')
# 'Mon Jul 11 03:06:17 +0000 2016'
#
# ('RT @barbs73: We SEE you Baton Rouge, DC, Dallas, STL, OKC, Memphis, St.Paul, '
#  'Fresno, Pittsb, SF, Portland, Miami, Columbus &amp; Berlin! #Black…')
# 'Mon Jul 11 03:06:18 +0000 2016'
#
# ("RT @xShorbie: So I'm curious... how many people live in Richmond, Virginia? "
#  'I just moved here would be lit to meet some new people :)')
# 'Mon Jul 11 03:06:19 +0000 2016'
#
# ('Can you recommend anyone for this #job? Retail Assistant Store Manager San '
#  'Francisco... - https://t.co/7ZPU6RXd7V https://t.co/zhP39K6r97')
# 'Mon Jul 11 03:06:19 +0000 2016'
#
# ('Oakland first-round pick A.J. Puk joins Lake Monsters.. Related Articles: '
#  'https://t.co/iDRNzWTNCh')
# 'Mon Jul 11 03:06:20 +0000 2016'
#
# ('RT @prisonculture: Here are some good and useful suggestions. '
#  'https://t.co/s3XMDxVDE6')
# 'Mon Jul 11 03:06:23 +0000 2016'
#
# '@FlowwJoe come to San Fran, I got you.'
# 'Mon Jul 11 03:06:24 +0000 2016'
#
# ('NorCal bitch if you like it or not\n'
#  "It is what it is, it's an Oakland thang\n"
#  'Whatchu doing shorty?\n'
#  "I'm just smoking mayne")
# 'Mon Jul 11 03:06:24 +0000 2016'
#
# ('Get your #burn on with Jenna starting tomorrow! Sign up for a class here: '
#  'https://t.co/Cd07rClhp6 #burnpilates #sf https://t.co/hldhwgnwoN')
# 'Mon Jul 11 03:06:24 +0000 2016'
#
# ('RT @MayaSchenwar: "We affirm that all contributions are political, militant, '
#  'and valued." I love this resource! \n'
#  '#BlackLivesMatter https://…')
# 'Mon Jul 11 03:06:26 +0000 2016'
#
# ('RT @A_S_Alexander: So many ways to show up! 26 Ways to Be in the Struggle '
#  'Beyond the Streets https://t.co/As2g4NMM3M #blacklivesmatter #mov…')
# 'Mon Jul 11 03:06:27 +0000 2016'
#
# ('JOB ALERT!: ADS Ambassador - SAVERS Location : Richmond CA US Work At Home. '
#  'Motivation to deliver exceptional... https://t.co/Gnp5NnzAjd')
# 'Mon Jul 11 03:06:31 +0000 2016'
#
# 'I saw Lincecum throw both his at SF and watched Kershaw throw his'
# 'Mon Jul 11 03:06:32 +0000 2016'
#
# ("@amylt7215 Fugitive sex offenders included on McAuliffe's rights restoration "
#  'list https://t.co/RJQyAb4Ej2 …')
# 'Mon Jul 11 03:06:33 +0000 2016'
#
# ('RT @LindaBanche: The universe is closer than you think A GIFT FROM THE STARS '
#  '#Regency #SF #PUYB #CR4U #IARTG https://t.co/YjaMIoCfX9 https:…')
# 'Mon Jul 11 03:06:33 +0000 2016'
#
# '@superic sorry. SF!'
# 'Mon Jul 11 03:06:36 +0000 2016'
#
# ('#gigs4u #gigs Preschool - Summer Camp Teacher/ Counselor '
#  'https://t.co/1zZ9BacSS8 #RVA #richmond #VA')
# 'Mon Jul 11 03:06:37 +0000 2016'
#
# 'I just wanna go to SF man.'
# 'Mon Jul 11 03:06:37 +0000 2016'
#
# ('RT @STRReform: STR industry is damaging to SF residential zoning everywhere  '
#  '#txlege @DonnaHowardTX #STR2out #homenothotel https://t.co/nGq…')
# 'Mon Jul 11 03:06:38 +0000 2016'
#
# ('Virgin Atlantic 787 is pretty (weird dot pattern is airport window) @ San '
#  'Francisco… https://t.co/G66Gy3eQMl')
# 'Mon Jul 11 03:06:38 +0000 2016'
#
# ('Final: Giants 4 Diamondbacks 0. WP: SF M Bumgarner (10-4) LP: ARI A Bradley '
#  '(3-5) (ESPN) https://t.co/TDi1eOfEzK Go Giants! #oddchamps')
# 'Mon Jul 11 03:06:39 +0000 2016'
#
# ("AZ 0,SF 4: Archie pitches well, but no run support. Can't think of anything "
#  'else that defined this game https://t.co/jaP3IB9dz9')
# 'Mon Jul 11 03:06:42 +0000 2016'
#
# ("AZ 0,SF 4: Archie pitches well, but no run support. Can't think of anything "
#  'else that defined this game https://t.co/TAv2RZRF4c')
# 'Mon Jul 11 03:06:42 +0000 2016'
#
# ('RT @kenna_gallagher: Sacramento, white water rafting, and San Fran trip📍😜 '
#  'https://t.co/dVys2kHM7M')
# 'Mon Jul 11 03:06:43 +0000 2016'
#
# ('RT @NataliaSports: Morning workouts start back up tomorrow morning at 8am!  '
#  '21 calendar days left to 2-A-Days!  Spread the word! SF..FS htt…')
# 'Mon Jul 11 03:06:45 +0000 2016'
#
# ('RT @CelticsHub: Current Nets depth chart: \n'
#  'PG: Lin, Levert\n'
#  'SG: Bogdanovic\n'
#  'SF: Hollis-Jefferson, Kilpatrick\n'
#  'PF: Booker, McCullough\n'
#  'C: Lopez,…')
# 'Mon Jul 11 03:06:46 +0000 2016'
#
# ('RT @prisonculture: Here are some good and useful suggestions. '
#  'https://t.co/s3XMDxVDE6')
# 'Mon Jul 11 03:06:47 +0000 2016'
#
# ('https://t.co/HWZNSaGt5B Rare San Francisco Giants Wool Rayon Hats Elastic '
#  'Painter Vintage Mlb Lot Of 2')
# 'Mon Jul 11 03:06:48 +0000 2016'
#
# ('WC2006: #POR wins "Most Entertaining Team" award, loses SF to #FRA.\n'
#  '\n'
#  'EURO2016: #POR plays "ugly football", beats #FRA in final to win Cup!')
# 'Mon Jul 11 03:06:50 +0000 2016'
#
# 'This Friday come to Richmond to see @buckymalone703 👺 https://t.co/ydgAxJfSMg'
# 'Mon Jul 11 03:06:51 +0000 2016'
#
# ("Vintage Unused AL MAR SEKI JAPAN #4010 SF-10 Knife/sheath 1980's - Bid Now! "
#  'Only $417.0 https://t.co/ngjJChY66X https://t.co/Y8Qmni9TlY')
# 'Mon Jul 11 03:06:53 +0000 2016'
#
# ('RT @MattGinellaGC: How good is sunset at Oakland Hills? '
#  'https://t.co/Iy4ZlPoS4O')
# 'Mon Jul 11 03:06:54 +0000 2016'
#
# ('I know the Warriors are dominating the Bay Area sports landscape but the '
#  'Giants have the best record in the MLB right now!!!')
# 'Mon Jul 11 03:06:56 +0000 2016'
#
# ("@FemalesForTrump Fugitive sex offenders included on McAuliffe's rights "
#  'restoration list https://t.co/RJQyAb4Ej2 …')
# 'Mon Jul 11 03:06:59 +0000 2016'
#
# ('RT @KianLawleyTeam: Kian and Jc with fans today in Richmond. '
#  'https://t.co/NalhxiSpIN')
# 'Mon Jul 11 03:07:00 +0000 2016'
#
# ('RT @BUSTER_MOJO: Madison Bumgarner just put the rest of the NL on notice. '
#  'The road to the series goes through San Francisco')
# 'Mon Jul 11 03:07:01 +0000 2016'
#
# ('Niles Notre Dame 2017 SF Jeameril Wilson @kingjeameril tells me he just '
#  'picked up offer from #Lewis @mikeweinstein55')
# 'Mon Jul 11 03:07:02 +0000 2016'
#
# ('@mlroach @murphstahoe I dunno, I never would have believed SF "progressives" '
#  'were so reactionary until moving here.')
# 'Mon Jul 11 03:07:04 +0000 2016'
#
# ('RT @KianLawleyTeam: Kian and Jc with fans today in Richmond. '
#  'https://t.co/DvHUXuU9aB')
# 'Mon Jul 11 03:07:04 +0000 2016'
#
# ("Corollary 1 to Berkeley's First Law of Mistakes: Always let an answer cool "
#  'off for awhile―it should not be used while hot.')
# 'Mon Jul 11 03:07:06 +0000 2016'
#
# ('I added a video to a @YouTube playlist https://t.co/CtL5qzd7UV Cafe | La '
#  'Promenade Café | Coffee | San Francisco | Review | Content')
# 'Mon Jul 11 03:07:08 +0000 2016'
#
# 'Frisco - Garn Again  https://t.co/wKBtX0hQxW'
# 'Mon Jul 11 03:07:09 +0000 2016'
#
# ("RT @blackvoices: From San Fran to D.C., many parts of America didn't stay "
#  'silent last night #BlackLivesMatter https://t.co/DhvY2yqOvB https…')
# 'Mon Jul 11 03:07:11 +0000 2016'
#
# 'SAN FRAN WASSS GOOOD'
# 'Mon Jul 11 03:07:11 +0000 2016'
#
# 'I have to own a house in Berkeley. Some how, some way.'
# 'Mon Jul 11 03:07:12 +0000 2016'
#
# ('RT @AllDefDigital: The Bay Area has their own slang, yadadamean?\n'
#  'https://t.co/hyz5hbel6m')
# 'Mon Jul 11 03:07:14 +0000 2016'
#
# ('RT @KianJcUpdates: Harrison joined the challenge | Richmond '
#  'https://t.co/c2vaT8DqyB')
# 'Mon Jul 11 03:07:16 +0000 2016'
#
# ("shieeeet are y'all going to the SF Anime Cosplay festival thing next "
#  "Saturday? not sure if i'll go and/or if i'll bother cosplaying")
# 'Mon Jul 11 03:07:20 +0000 2016'
#
# 'RT @_briannal0l: I just wanna go to SF man.'
# 'Mon Jul 11 03:07:20 +0000 2016'
#
# ("RT @LANow: Oakland police scandal raises fears about the city's fight "
#  'against sex trafficking https://t.co/hgJyoLRsr7')
# 'Mon Jul 11 03:07:21 +0000 2016'
#
# ('RT @rBasicIncome: On #BasicIncome: Oakland is trialling a universal basic '
#  'income for all https://t.co/z2dFRubz6y')
# 'Mon Jul 11 03:07:22 +0000 2016'
#
# ('RT @PatrckStatic: Had a beautifully gorgeous and relaxing day in San Fran '
#  'with my family! Was much needed! Time to record some videos now \\…')
# 'Mon Jul 11 03:07:24 +0000 2016'
#
# ('RT @A_S_Alexander: So many ways to show up! 26 Ways to Be in the Struggle '
#  'Beyond the Streets https://t.co/As2g4NMM3M #blacklivesmatter #mov…')
# 'Mon Jul 11 03:07:25 +0000 2016'
#
# ('Final: Giants 4 Diamondbacks 0. WP: SF M Bumgarner (10-4) LP: ARI A Bradley '
#  '(3-5) (ESPN) https://t.co/Szm4Kv1DAx')
# 'Mon Jul 11 03:07:27 +0000 2016'
#
# ('+++ SAN FRANCISCO RUSH 2049 Sega Dreamcast Game COMPLETE +++ '
#  'https://t.co/swWLuYuH1K https://t.co/brLkUH4DFp')
# 'Mon Jul 11 03:07:27 +0000 2016'
#
# 'Good night, San Fran! https://t.co/bcI2ZGxkKA'
# 'Mon Jul 11 03:07:28 +0000 2016'
#
# ('Bay area sports putting out one kind of decade run here! '
#  '#takenotice#specialstuff')
# 'Mon Jul 11 03:07:28 +0000 2016'
#
# ('EN DIRECT sur #Periscope : Ok Mada Style, Who speak english ? #fuckfrance  '
#  'https://t.co/zzGQIxMoeZ')
# 'Mon Jul 11 03:07:28 +0000 2016'
#
# ('RT @A_S_Alexander: So many ways to show up! 26 Ways to Be in the Struggle '
#  'Beyond the Streets https://t.co/As2g4NMM3M #blacklivesmatter #mov…')
# 'Mon Jul 11 03:07:29 +0000 2016'
#
# ('RT @AntiochTweets: How people from the Bay Area be at weddings: '
#  'https://t.co/XVdMI4YGgx')
# 'Mon Jul 11 03:07:30 +0000 2016'
#
# ('Oakland CA USA - Dentistry Position in California - A Barton client in '
#  'California is looking for a dentist wh... https://t.co/TOD65AO9xU')
# 'Mon Jul 11 03:07:32 +0000 2016'
#
# ('RT @LovexAliah: 1000 Man March in Richmond next weekend, definitely tryna be '
#  'out there for that! #BlackLivesMatter #RVA')
# 'Mon Jul 11 03:07:34 +0000 2016'
#
# ('Municipality of San Francisco joins Nutrition Month Celebration.  \n'
#  'Theme: First 1000 days ni baby pahalagahan... https://t.co/zr0BvZkLPk')
# 'Mon Jul 11 03:07:36 +0000 2016'
#
# 'RT @jaylenbledsoe: @FlowwJoe come to San Fran, I got you.'
# 'Mon Jul 11 03:07:37 +0000 2016'
#
# 'Oh, that year. 😈  https://t.co/Ulccny7O4R'
# 'Mon Jul 11 03:07:37 +0000 2016'
#
# ('RT @dragonhousemma: Thursday night No Gi BJJ  light rolling warm up '
#  '💪#DragonHouse #SF #Mma #ClovisSilvaBJJ #Asian @… https://t.co/J4me9DoEdc')
# 'Mon Jul 11 03:07:38 +0000 2016'
#
# ('Talking to Kids about Racism and Justice - Oakland Library '
#  'https://t.co/OCqYLXf0w2')
# 'Mon Jul 11 03:07:38 +0000 2016'
#
# ("💗awwwwwww chit I'm wet w e t ❕horny for You ...my baby bae bar again💓! I "
#  'need to sf Miami SF YOU!!!july v v w\\ me..when natural ...Or like 🎳')
# 'Mon Jul 11 03:07:39 +0000 2016'
#
# ('RT @streetartmagic: "Men Playing God\'s Game" by Nychos in San Francisco '
#  '#streetart #graffiti #art https://t.co/ybRhJueipQ')
# 'Mon Jul 11 03:07:40 +0000 2016'
#
# ('RT @JcCaylenTeam: KnJ with fans in Richmond, VA😛🤘🏼 #KnJRichmond '
#  'https://t.co/iCgPXtM6vG')
# 'Mon Jul 11 03:07:41 +0000 2016'

# %%
len(data)
# Out:
# 479
