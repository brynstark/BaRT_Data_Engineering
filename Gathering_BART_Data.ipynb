# %% [markdown]
# # Obtaining BART Data and Writing to JSON File
#
#
# - [BART API testing](#section1)
# - [Loading BART Data into JSON File](#section2)

# %% [markdown]
# <a id='section1'></a>

# %% [markdown]
# ## BART API testing

# %%
import requests
import xmltodict

# %%
# This is an API call for BART's routesched, which gives the schedule of a certain route.
# In this case, the Fremont train:
response = requests.get('http://api.bart.gov/api/sched.aspx?cmd=routesched&route=6&key=MW9S-E7SL-26DU-VV8V')

# %%
text = response.content

# %%
bart = xmltodict.parse(text)

# %%
bart.keys()
# Out:
# odict_keys(['root'])

# %%
bart['root'].keys()
# Out:
# odict_keys(['uri', 'date', 'sched_num', 'route', 'message'])

# %%
bart['root']['route'].keys()
# Out:
# odict_keys(['train'])

# %%
# If we walk the dict to 'train', it's a list of all the trains on the route and a dict of their schedules.
bart['root']['route']['train'][:2]
# Out:
# [OrderedDict([('@index', '1'),
#               ('stop',
#                [OrderedDict([('@station', 'DALY'),
#                              ('@origTime', '6:13 AM'),
#                              ('@bikeflag', '1')]),
#                 OrderedDict([('@station', 'BALB'),
#                              ('@origTime', '6:17 AM'),
#                              ('@bikeflag', '1')]),
#                 OrderedDict([('@station', 'GLEN'),
#                              ('@origTime', '6:19 AM'),
#                              ('@bikeflag', '1')]),
#                 OrderedDict([('@station', '24TH'),
#                              ('@origTime', '6:22 AM'),
#                              ('@bikeflag', '1')]),
#                 OrderedDict([('@station', '16TH'),
#                              ('@origTime', '6:24 AM'),
#                              ('@bikeflag', '1')]),
#                 OrderedDict([('@station', 'CIVC'),
#                              ('@origTime', '6:26 AM'),
#                              ('@bikeflag', '1')]),
#                 OrderedDict([('@station', 'POWL'),
#                              ('@origTime', '6:27 AM'),
#                              ('@bikeflag', '1')]),
#                 OrderedDict([('@station', 'MONT'),
#                              ('@origTime', '6:29 AM'),
#                              ('@bikeflag', '1')]),
#                 OrderedDict([('@station', 'EMBR'),
#                              ('@origTime', '6:30 AM'),
#                              ('@bikeflag', '1')]),
#                 OrderedDict([('@station', 'WOAK'),
#                              ('@origTime', '6:37 AM'),
#                              ('@bikeflag', '1')]),
#                 OrderedDict([('@station', 'LAKE'),
#                              ('@origTime', '6:43 AM'),
#                              ('@bikeflag', '1')]),
#                 OrderedDict([('@station', 'FTVL'),
#                              ('@origTime', '6:46 AM'),
#                              ('@bikeflag', '1')]),
#                 OrderedDict([('@station', 'COLS'),
#                              ('@origTime', '6:50 AM'),
#                              ('@bikeflag', '1')]),
#                 OrderedDict([('@station', 'SANL'),
#                              ('@origTime', '6:54 AM'),
#                              ('@bikeflag', '1')]),
#                 OrderedDict([('@station', 'BAYF'),
#                              ('@origTime', '6:57 AM'),
#                              ('@bikeflag', '1')]),
#                 OrderedDict([('@station', 'HAYW'),
#                              ('@origTime', '7:01 AM'),
#                              ('@bikeflag', '1')]),
#                 OrderedDict([('@station', 'SHAY'),
#                              ('@origTime', '7:05 AM'),
#                              ('@bikeflag', '1')]),
#                 OrderedDict([('@station', 'UCTY'),
#                              ('@origTime', '7:10 AM'),
#                              ('@bikeflag', '1')]),
#                 OrderedDict([('@station', 'FRMT'),
#                              ('@origTime', '7:16 AM'),
#                              ('@bikeflag', '1')])])]),
#  OrderedDict([('@index', '2'),
#               ('stop',
#                [OrderedDict([('@station', 'DALY'),
#                              ('@origTime', '6:28 AM'),
#                              ('@bikeflag', '1')]),
#                 OrderedDict([('@station', 'BALB'),
#                              ('@origTime', '6:32 AM'),
#                              ('@bikeflag', '1')]),
#                 OrderedDict([('@station', 'GLEN'),
#                              ('@origTime', '6:34 AM'),
#                              ('@bikeflag', '1')]),
#                 OrderedDict([('@station', '24TH'),
#                              ('@origTime', '6:37 AM'),
#                              ('@bikeflag', '1')]),
#                 OrderedDict([('@station', '16TH'),
#                              ('@origTime', '6:39 AM'),
#                              ('@bikeflag', '1')]),
#                 OrderedDict([('@station', 'CIVC'),
#                              ('@origTime', '6:41 AM'),
#                              ('@bikeflag', '1')]),
#                 OrderedDict([('@station', 'POWL'),
#                              ('@origTime', '6:42 AM'),
#                              ('@bikeflag', '1')]),
#                 OrderedDict([('@station', 'MONT'),
#                              ('@origTime', '6:44 AM'),
#                              ('@bikeflag', '1')]),
#                 OrderedDict([('@station', 'EMBR'),
#                              ('@origTime', '6:45 AM'),
#                              ('@bikeflag', '1')]),
#                 OrderedDict([('@station', 'WOAK'),
#                              ('@origTime', '6:52 AM'),
#                              ('@bikeflag', '1')]),
#                 OrderedDict([('@station', 'LAKE'),
#                              ('@origTime', '6:58 AM'),
#                              ('@bikeflag', '1')]),
#                 OrderedDict([('@station', 'FTVL'),
#                              ('@origTime', '7:01 AM'),
#                              ('@bikeflag', '1')]),
#                 OrderedDict([('@station', 'COLS'),
#                              ('@origTime', '7:05 AM'),
#                              ('@bikeflag', '1')]),
#                 OrderedDict([('@station', 'SANL'),
#                              ('@origTime', '7:09 AM'),
#                              ('@bikeflag', '1')]),
#                 OrderedDict([('@station', 'BAYF'),
#                              ('@origTime', '7:12 AM'),
#                              ('@bikeflag', '1')]),
#                 OrderedDict([('@station', 'HAYW'),
#                              ('@origTime', '7:16 AM'),
#                              ('@bikeflag', '1')]),
#                 OrderedDict([('@station', 'SHAY'),
#                              ('@origTime', '7:20 AM'),
#                              ('@bikeflag', '1')]),
#                 OrderedDict([('@station', 'UCTY'),
#                              ('@origTime', '7:25 AM'),
#                              ('@bikeflag', '1')]),
#                 OrderedDict([('@station', 'FRMT'),
#                              ('@origTime', '7:31 AM'),
#                              ('@bikeflag', '1')])])])]

# %%
bart['root']['date']
# Out:
# '7/11/2016'

# %%
type(bart)
# Out:
# collections.OrderedDict

# %%
len(bart)
# Out:
# 1

# %%
len(bart['root'])
# Out:
# 5

# %%
len(bart['root']['route']['train'])
# Out:
# 52

# %%
type(bart['root']['route']['train'])
# Out:
# list

# %%
bart['root']['route']['train'][0]['stop']
# Out:
# [OrderedDict([('@station', 'DALY'),
#               ('@origTime', '6:13 AM'),
#               ('@bikeflag', '1')]),
#  OrderedDict([('@station', 'BALB'),
#               ('@origTime', '6:17 AM'),
#               ('@bikeflag', '1')]),
#  OrderedDict([('@station', 'GLEN'),
#               ('@origTime', '6:19 AM'),
#               ('@bikeflag', '1')]),
#  OrderedDict([('@station', '24TH'),
#               ('@origTime', '6:22 AM'),
#               ('@bikeflag', '1')]),
#  OrderedDict([('@station', '16TH'),
#               ('@origTime', '6:24 AM'),
#               ('@bikeflag', '1')]),
#  OrderedDict([('@station', 'CIVC'),
#               ('@origTime', '6:26 AM'),
#               ('@bikeflag', '1')]),
#  OrderedDict([('@station', 'POWL'),
#               ('@origTime', '6:27 AM'),
#               ('@bikeflag', '1')]),
#  OrderedDict([('@station', 'MONT'),
#               ('@origTime', '6:29 AM'),
#               ('@bikeflag', '1')]),
#  OrderedDict([('@station', 'EMBR'),
#               ('@origTime', '6:30 AM'),
#               ('@bikeflag', '1')]),
#  OrderedDict([('@station', 'WOAK'),
#               ('@origTime', '6:37 AM'),
#               ('@bikeflag', '1')]),
#  OrderedDict([('@station', 'LAKE'),
#               ('@origTime', '6:43 AM'),
#               ('@bikeflag', '1')]),
#  OrderedDict([('@station', 'FTVL'),
#               ('@origTime', '6:46 AM'),
#               ('@bikeflag', '1')]),
#  OrderedDict([('@station', 'COLS'),
#               ('@origTime', '6:50 AM'),
#               ('@bikeflag', '1')]),
#  OrderedDict([('@station', 'SANL'),
#               ('@origTime', '6:54 AM'),
#               ('@bikeflag', '1')]),
#  OrderedDict([('@station', 'BAYF'),
#               ('@origTime', '6:57 AM'),
#               ('@bikeflag', '1')]),
#  OrderedDict([('@station', 'HAYW'),
#               ('@origTime', '7:01 AM'),
#               ('@bikeflag', '1')]),
#  OrderedDict([('@station', 'SHAY'),
#               ('@origTime', '7:05 AM'),
#               ('@bikeflag', '1')]),
#  OrderedDict([('@station', 'UCTY'),
#               ('@origTime', '7:10 AM'),
#               ('@bikeflag', '1')]),
#  OrderedDict([('@station', 'FRMT'),
#               ('@origTime', '7:16 AM'),
#               ('@bikeflag', '1')])]

# %% [markdown]
# Now to write this data to a JSON file so that we can load it into PostgreSQL.

# %%
import json

# %%
bart_as_string = json.dumps(bart['root'])

# %%
print(bart_as_string)
# Out:
# {"uri": "http://api.bart.gov/api/sched.aspx?cmd=routesched&route=6", "date": "7/11/2016", "sched_num": "39", "route": {"train": [{"@index": "1", "stop": [{"@station": "DALY", "@origTime": "6:13 AM", "@bikeflag": "1"}, {"@station": "BALB", "@origTime": "6:17 AM", "@bikeflag": "1"}, {"@station": "GLEN", "@origTime": "6:19 AM", "@bikeflag": "1"}, {"@station": "24TH", "@origTime": "6:22 AM", "@bikeflag": "1"}, {"@station": "16TH", "@origTime": "6:24 AM", "@bikeflag": "1"}, {"@station": "CIVC", "@origTime": "6:26 AM", "@bikeflag": "1"}, {"@station": "POWL", "@origTime": "6:27 AM", "@bikeflag": "1"}, {"@station": "MONT", "@origTime": "6:29 AM", "@bikeflag": "1"}, {"@station": "EMBR", "@origTime": "6:30 AM", "@bikeflag": "1"}, {"@station": "WOAK", "@origTime": "6:37 AM", "@bikeflag": "1"}, {"@station": "LAKE", "@origTime": "6:43 AM", "@bikeflag": "1"}, {"@station": "FTVL", "@origTime": "6:46 AM", "@bikeflag": "1"}, {"@station": "COLS", "@origTime": "6:50 AM", "@bikeflag": "1"}, {"@station": "SANL", "@origTime": "6:54 AM", "@bikeflag": "1"}, {"@station": "BAYF", "@origTime": "6:57 AM", "@bikeflag": "1"}, {"@station": "HAYW", "@origTime": "7:01 AM", "@bikeflag": "1"}, {"@station": "SHAY", "@origTime": "7:05 AM", "@bikeflag": "1"}, {"@station": "UCTY", "@origTime": "7:10 AM", "@bikeflag": "1"}, {"@station": "FRMT", "@origTime": "7:16 AM", "@bikeflag": "1"}]}, {"@index": "2", "stop": [{"@station": "DALY", "@origTime": "6:28 AM", "@bikeflag": "1"}, {"@station": "BALB", "@origTime": "6:32 AM", "@bikeflag": "1"}, {"@station": "GLEN", "@origTime": "6:34 AM", "@bikeflag": "1"}, {"@station": "24TH", "@origTime": "6:37 AM", "@bikeflag": "1"}, {"@station": "16TH", "@origTime": "6:39 AM", "@bikeflag": "1"}, {"@station": "CIVC", "@origTime": "6:41 AM", "@bikeflag": "1"}, {"@station": "POWL", "@origTime": "6:42 AM", "@bikeflag": "1"}, {"@station": "MONT", "@origTime": "6:44 AM", "@bikeflag": "1"}, {"@station": "EMBR", "@origTime": "6:45 AM", "@bikeflag": "1"}, {"@station": "WOAK", "@origTime": "6:52 AM", "@bikeflag": "1"}, {"@station": "LAKE", "@origTime": "6:58 AM", "@bikeflag": "1"}, {"@station": "FTVL", "@origTime": "7:01 AM", "@bikeflag": "1"}, {"@station": "COLS", "@origTime": "7:05 AM", "@bikeflag": "1"}, {"@station": "SANL", "@origTime": "7:09 AM", "@bikeflag": "1"}, {"@station": "BAYF", "@origTime": "7:12 AM", "@bikeflag": "1"}, {"@station": "HAYW", "@origTime": "7:16 AM", "@bikeflag": "1"}, {"@station": "SHAY", "@origTime": "7:20 AM", "@bikeflag": "1"}, {"@station": "UCTY", "@origTime": "7:25 AM", "@bikeflag": "1"}, {"@station": "FRMT", "@origTime": "7:31 AM", "@bikeflag": "1"}]}, {"@index": "3", "stop": [{"@station": "DALY", "@origTime": "6:43 AM", "@bikeflag": "1"}, {"@station": "BALB", "@origTime": "6:47 AM", "@bikeflag": "1"}, {"@station": "GLEN", "@origTime": "6:49 AM", "@bikeflag": "1"}, {"@station": "24TH", "@origTime": "6:52 AM", "@bikeflag": "1"}, {"@station": "16TH", "@origTime": "6:54 AM", "@bikeflag": "1"}, {"@station": "CIVC", "@origTime": "6:56 AM", "@bikeflag": "1"}, {"@station": "POWL", "@origTime": "6:57 AM", "@bikeflag": "1"}, {"@station": "MONT", "@origTime": "6:59 AM", "@bikeflag": "1"}, {"@station": "EMBR", "@origTime": "7:00 AM", "@bikeflag": "1"}, {"@station": "WOAK", "@origTime": "7:07 AM", "@bikeflag": "1"}, {"@station": "LAKE", "@origTime": "7:13 AM", "@bikeflag": "1"}, {"@station": "FTVL", "@origTime": "7:16 AM", "@bikeflag": "1"}, {"@station": "COLS", "@origTime": "7:20 AM", "@bikeflag": "1"}, {"@station": "SANL", "@origTime": "7:24 AM", "@bikeflag": "1"}, {"@station": "BAYF", "@origTime": "7:27 AM", "@bikeflag": "1"}, {"@station": "HAYW", "@origTime": "7:31 AM", "@bikeflag": "1"}, {"@station": "SHAY", "@origTime": "7:35 AM", "@bikeflag": "1"}, {"@station": "UCTY", "@origTime": "7:40 AM", "@bikeflag": "1"}, {"@station": "FRMT", "@origTime": "7:46 AM", "@bikeflag": "1"}]}, {"@index": "4", "stop": [{"@station": "DALY", "@origTime": "6:58 AM", "@bikeflag": "1"}, {"@station": "BALB", "@origTime": "7:02 AM", "@bikefl ...

# %%
with open('bart_data.json', 'a') as f:
    f.write(bart_as_string)

# %% [markdown]
# Reminder, this was only for one route, Daly City-Fremont. We need all other routes, as well.

# %% [markdown]
# <a id='section2'></a>

# %% [markdown]
# # Loading BART data into JSON file

# %% [markdown]
# BART routes are numbered 1 through 12. With that in mind, let's collect the JSON of the schedule for each route and append it to one file.

# %%
import requests
import xmltodict
import json

# %%
# Code to obtain the url's for the API calls for each route, 1-8, 11-12, and 19-20.
for route_num in range(1,9):
    url = 'http://api.bart.gov/api/sched.aspx?cmd=routesched&route={0}&key=MW9S-E7SL-26DU-VV8V'.format(route_num)
    print(url)
for route_num in [11,12,19,20]:
    url = 'http://api.bart.gov/api/sched.aspx?cmd=routesched&route={0}&key=MW9S-E7SL-26DU-VV8V'.format(route_num)
    print(url)
# Out:
# http://api.bart.gov/api/sched.aspx?cmd=routesched&route=1&key=MW9S-E7SL-26DU-VV8V
# http://api.bart.gov/api/sched.aspx?cmd=routesched&route=2&key=MW9S-E7SL-26DU-VV8V
# http://api.bart.gov/api/sched.aspx?cmd=routesched&route=3&key=MW9S-E7SL-26DU-VV8V
# http://api.bart.gov/api/sched.aspx?cmd=routesched&route=4&key=MW9S-E7SL-26DU-VV8V
# http://api.bart.gov/api/sched.aspx?cmd=routesched&route=5&key=MW9S-E7SL-26DU-VV8V
# http://api.bart.gov/api/sched.aspx?cmd=routesched&route=6&key=MW9S-E7SL-26DU-VV8V
# http://api.bart.gov/api/sched.aspx?cmd=routesched&route=7&key=MW9S-E7SL-26DU-VV8V
# http://api.bart.gov/api/sched.aspx?cmd=routesched&route=8&key=MW9S-E7SL-26DU-VV8V
# http://api.bart.gov/api/sched.aspx?cmd=routesched&route=11&key=MW9S-E7SL-26DU-VV8V
# http://api.bart.gov/api/sched.aspx?cmd=routesched&route=12&key=MW9S-E7SL-26DU-VV8V
# http://api.bart.gov/api/sched.aspx?cmd=routesched&route=19&key=MW9S-E7SL-26DU-VV8V
# http://api.bart.gov/api/sched.aspx?cmd=routesched&route=20&key=MW9S-E7SL-26DU-VV8V

# %%
routes = [i for i in range(1,9)]
routes.extend([11,12,19,20])
print(routes)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 11, 12, 19, 20]

# %%
def get_BART_schedule(route_num):
    # URL to obtain the schedule data for route number [route_num]
    url = 'http://api.bart.gov/api/sched.aspx?cmd=routesched&route={0}&key=MW9S-E7SL-26DU-VV8V'.format(route_num)
    response = requests.get(url)  # making API call
    text = response.content  # content obtained
    bart = xmltodict.parse(text)  # Parsing xml content to be ordered dictionary
    return bart

# %%
# For each BART route
for route_num in routes:
    sched = get_BART_schedule(route_num)  # Get ordered dict of schedule for this route
    sched_as_string = json.dumps(sched['root'])  # Converting dict to string containing JSON object
    with open('bart_schedules_by_route.json', 'a') as f:
        f.write(sched_as_string + '\n')   # Appending to the file as a new row

# %% [markdown]
# Checking the file:

# %%
with open('bart_schedules_by_route.json', 'r') as f:
    txt = f.read()

# %%
len(txt)
# Out:
# 1051060

# %%
txt.split('\n')[0]
# Out:
# '{"uri": "http://api.bart.gov/api/sched.aspx?cmd=routesched&route=1", "date": "7/13/2016", "sched_num": "39", "route": {"train": [{"@index": "1", "stop": [{"@station": "PITT", "@origTime": "4:02 AM", "@bikeflag": "1"}, {"@station": "NCON", "@origTime": "4:08 AM", "@bikeflag": "1"}, {"@station": "CONC", "@origTime": "4:12 AM", "@bikeflag": "1"}, {"@station": "PHIL", "@origTime": "4:17 AM", "@bikeflag": "1"}, {"@station": "WCRK", "@origTime": "4:20 AM", "@bikeflag": "1"}, {"@station": "LAFY", "@origTime": "4:25 AM", "@bikeflag": "1"}, {"@station": "ORIN", "@origTime": "4:30 AM", "@bikeflag": "1"}, {"@station": "ROCK", "@origTime": "4:35 AM", "@bikeflag": "1"}, {"@station": "MCAR", "@origTime": "4:38 AM", "@bikeflag": "1"}, {"@station": "19TH", "@origTime": "4:42 AM", "@bikeflag": "1"}, {"@station": "12TH", "@origTime": "4:43 AM", "@bikeflag": "1"}, {"@station": "WOAK", "@origTime": "4:48 AM", "@bikeflag": "1"}, {"@station": "EMBR", "@origTime": "4:55 AM", "@bikeflag": "1"}, {"@station": "MONT", "@origTime": "4:56 AM", "@bikeflag": "1"}, {"@station": "POWL", "@origTime": "4:58 AM", "@bikeflag": "1"}, {"@station": "CIVC", "@origTime": "4:59 AM", "@bikeflag": "1"}, {"@station": "16TH", "@origTime": "5:01 AM", "@bikeflag": "1"}, {"@station": "24TH", "@origTime": "5:03 AM", "@bikeflag": "1"}, {"@station": "GLEN", "@origTime": "5:06 AM", "@bikeflag": "1"}, {"@station": "BALB", "@origTime": "5:08 AM", "@bikeflag": "1"}, {"@station": "DALY", "@origTime": "5:12 AM", "@bikeflag": "1"}, {"@station": "COLM", "@origTime": "5:16 AM", "@bikeflag": "1"}, {"@station": "SSAN", "@origTime": "5:19 AM", "@bikeflag": "1"}, {"@station": "SBRN", "@origTime": "5:23 AM", "@bikeflag": "1"}, {"@station": "SFIA", "@origTime": "5:28 AM", "@bikeflag": "1"}, {"@station": "MLBR", "@bikeflag": "1"}]}, {"@index": "2", "stop": [{"@station": "PITT", "@origTime": "4:17 AM", "@bikeflag": "1"}, {"@station": "NCON", "@origTime": "4:23 AM", "@bikeflag": "1"}, {"@station": "CONC", "@origTime": "4:27 AM", "@bikeflag": "1"}, {"@station": "PHIL", "@origTime": "4:32 AM", "@bikeflag": "1"}, {"@station": "WCRK", "@origTime": "4:35 AM", "@bikeflag": "1"}, {"@station": "LAFY", "@origTime": "4:40 AM", "@bikeflag": "1"}, {"@station": "ORIN", "@origTime": "4:45 AM", "@bikeflag": "1"}, {"@station": "ROCK", "@origTime": "4:50 AM", "@bikeflag": "1"}, {"@station": "MCAR", "@origTime": "4:53 AM", "@bikeflag": "1"}, {"@station": "19TH", "@origTime": "4:57 AM", "@bikeflag": "1"}, {"@station": "12TH", "@origTime": "4:58 AM", "@bikeflag": "1"}, {"@station": "WOAK", "@origTime": "5:03 AM", "@bikeflag": "1"}, {"@station": "EMBR", "@origTime": "5:10 AM", "@bikeflag": "1"}, {"@station": "MONT", "@origTime": "5:11 AM", "@bikeflag": "1"}, {"@station": "POWL", "@origTime": "5:13 AM", "@bikeflag": "1"}, {"@station": "CIVC", "@origTime": "5:14 AM", "@bikeflag": "1"}, {"@station": "16TH", "@origTime": "5:16 AM", "@bikeflag": "1"}, {"@station": "24TH", "@origTime": "5:18 AM", "@bikeflag": "1"}, {"@station": "GLEN", "@origTime": "5:21 AM", "@bikeflag": "1"}, {"@station": "BALB", "@origTime": "5:23 AM", "@bikeflag": "1"}, {"@station": "DALY", "@origTime": "5:27 AM", "@bikeflag": "1"}, {"@station": "COLM", "@origTime": "5:31 AM", "@bikeflag": "1"}, {"@station": "SSAN", "@origTime": "5:34 AM", "@bikeflag": "1"}, {"@station": "SBRN", "@origTime": "5:38 AM", "@bikeflag": "1"}, {"@station": "SFIA", "@origTime": "5:43 AM", "@bikeflag": "1"}, {"@station": "MLBR", "@bikeflag": "1"}]}, {"@index": "3", "stop": [{"@station": "PITT", "@origTime": "4:32 AM", "@bikeflag": "1"}, {"@station": "NCON", "@origTime": "4:38 AM", "@bikeflag": "1"}, {"@station": "CONC", "@origTime": "4:42 AM", "@bikeflag": "1"}, {"@station": "PHIL", "@origTime": "4:47 AM", "@bikeflag": "1"}, {"@station": "WCRK", "@origTime": "4:50 AM", "@bikeflag": "1"}, {"@station": "LAFY", "@origTime": "4:55 AM", "@bikeflag": "1"}, {"@station": "ORIN", "@origTime": "5:00 AM", "@bikeflag": "1"}, {"@station": "ROCK", "@origTime": "5:05 AM", "@bikeflag": "1"}, ...

# %%
txt.split('\n')[-1]
# Out:
# ''

# %% [markdown]
# __Nice. Now bart_schedules_by_route.json has one row for each route (and an empty row at the end).__
